# %% [markdown]
# # AIS project

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from geopy.distance import geodesic
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Input
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import xgboost as xgb

import geopy.distance

# %% [markdown]
# ### Load data from CSV

# %%
# Load data
ais_train_import = pd.read_csv('data/ais_train.csv', sep='|')  # Adjust file path
ais_eval_import = pd.read_csv('data/ais_test.csv', sep=',')  # Adjust file path

vessels_import = pd.read_csv('data/vessels.csv', sep='|')  # Adjust file path
ports_import = pd.read_csv('data/ports.csv', sep='|')  # Adjust file path
schedules_import = pd.read_csv('data/schedules_to_may_2024.csv', sep='|')  # Adjust file path
# Convert latitude and longitude to float32
ais_train_import['latitude'] = ais_train_import['latitude'].astype('float32')
ais_train_import['longitude'] = ais_train_import['longitude'].astype('float32')
ports_import['latitude'] = ports_import['latitude'].astype('float32')
ports_import['longitude'] = ports_import['longitude'].astype('float32')
schedules_import['portLatitude'] = schedules_import['portLatitude'].astype('float32')
schedules_import['portLongitude'] = schedules_import['portLongitude'].astype('float32')

# %% [markdown]
# ### Preprocess data

# %%
# Preprocess data

# Make copies of the loaded datasets
# time|cog|sog|rot|heading|navstat|etaRaw|latitude|longitude|vesselId|portId
train = ais_train_import[['vesselId', 'time', 'cog', 'sog', 'rot', 'heading', 'navstat', 'latitude', 'longitude', 'portId']]
eval = ais_eval_import[['ID', 'vesselId', 'time']].copy()
vessels = vessels_import[['vesselId', 'shippingLineId']].copy()
ports = ports_import[['portId', 'longitude', 'latitude']].copy()
schedules = schedules_import[['vesselId', 'shippingLineId', 'arrivalDate', 'sailingDate', 'portId', 'portLatitude', 'portLongitude']].copy()

ports = ports.rename(columns={'longitude': 'portLongitude', 'latitude': 'portLatitude'})

# Dropp missing schedules
schedules = schedules.dropna()

# Connect data to AIS data
train = pd.merge(train, vessels, on='vesselId', how='left')
train = pd.merge(train, ports, on='portId', how='left')

eval = pd.merge(eval, vessels, on='vesselId', how='left')


# Convert time to datetime
train['time'] = pd.to_datetime(train['time'])
eval['time'] = pd.to_datetime(eval['time'])

# Label encode vesselId
le_vesselId = LabelEncoder()
le_vesselId.fit(train['vesselId'])
train['vesselId'] = le_vesselId.transform(train['vesselId'])
eval['vesselId'] = le_vesselId.transform(eval['vesselId'])

# Label encode portId
le_portId = LabelEncoder()
le_portId.fit(pd.concat([train['portId'], schedules['portId']]))
train['portId'] = le_portId.transform(train['portId'])
schedules['portId'] = le_portId.transform(schedules['portId'])
#eval['portId'] = le_portId.transform(eval['portId'])

display(train)
display(eval)
# Out:
#          vesselId                time    cog   sog  rot  heading  navstat  \
# 0              50 2024-01-01 00:00:25  284.0   0.7    0       88        0
# 1             189 2024-01-01 00:00:36  109.6   0.0   -6      347        1
# 2             432 2024-01-01 00:01:45  111.0  11.0    0      112        0
# 3             110 2024-01-01 00:03:11   96.4   0.0    0      142        1
# 4             356 2024-01-01 00:03:51  214.0  19.7    0      215        0
# ...           ...                 ...    ...   ...  ...      ...      ...
# 1522060       682 2024-05-07 23:59:07  359.1  13.4    0        1        0
# 1522061        85 2024-05-07 23:59:08   12.3  17.1    0       13        0
# 1522062       459 2024-05-07 23:59:08  269.8  14.9   -1      270        0
# 1522063       596 2024-05-07 23:59:08    8.0  18.7    0        6        0
# 1522064       637 2024-05-07 23:59:08  336.0  14.3    5      337        0
#
#           latitude   longitude  portId            shippingLineId  \
# 0       -34.743698  -57.851299      40  61ec65aea8cafc0e93f0e900
# 1         8.894400  -79.479393     682  61be24564ea00ae59d0fe37a
# 2        39.190651  -76.475670     358  61be24564ea00ae59d0fe379
# 3       -34.411888  151.020676      18  61a8e672f9cba188601e84ac
# 4        35.883789   -5.916360     613  61be24564ea00ae59d0fe37a
# ...            ...         ...     ...                       ...
# 1522060  52.191311   -5.822230     568  61a8e673f9cba188601e84b3
# 1522061  38.961418  -12.005020     686  61a8e672f9cba188601e84ac
# 1522062  49.713718   -5.220420     759  61a8e673f9cba188601e84b9
# 1522063  38.278950   10.782800     135  61ec6303a8cafc0e93f0e8f3
# 1522064  38.986351  -75.132751     408  61be24564ea00ae59d0fe379
#
#          portLongitude  portLatitude
# 0           -71.618889    -33.587502
# 1           -79.532997      8.967000
# 2           -76.558891     39.232498
# 3           150.899445    -34.462502
# 4            -5.817000     35.783001
# ...                ...           ...
# 1522060      -7.100000     52.250000
# 1522061      -9.417000     38.700001
# 1522062      -5.317000     50.083000
# 1522063      11.780833     42.098888
# 1522064     -75.521667     39.716667
#
# [1522065 rows x 13 columns]
#           ID  vesselId                time            shippingLineId
# 0          0        84 2024-05-08 00:03:16  61a8e672f9cba188601e84ac
# 1          1       623 2024-05-08 00:06:17  61be24574ea00ae59d0fe388
# 2          2       596 2024-05-08 00:10:02  61ec6303a8cafc0e93f0e8f3
# 3          3       542 2024-05-08 00:10:34  61be24564ea00ae59d0fe37a
# 4          4         1 2024-05-08 00:12:27  61ec94f1a8cafc0e93f0e92a
# ...      ...       ...                 ...                       ...
# 51734  51734        48 2024-05-12 23:59:58  61a8e672f9cba188601e84ab
# 51735  51735       110 2024-05-12 23:59:58  61a8e672f9cba188601e84ac
# 51736  51736       610 2024-05-12 23:59:58  61a8e673f9cba188601e84b9
# 51737  51737       574 2024-05-12 23:59:58  61ec643ca8cafc0e93f0e8f9
# 51738  51738        82 2024-05-12 23:59:58  61a8e672f9cba188601e84ac
#
# [51739 rows x 4 columns]

# %% [markdown]
# ### Feature engineering

# %%
# Feature engineering

def time_features(df):
    df['hour'] = df['time'].dt.hour
    df['day'] = df['time'].dt.day
    df['dayofweek'] = df['time'].dt.dayofweek
    df['month'] = df['time'].dt.month

    # Cycle features
    df['sin_hour'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['cos_hour'] = np.cos(2 * np.pi * df['hour'] / 24)
    df['sin_day'] = np.sin(2 * np.pi * df['day'] / 30)
    df['cos_day'] = np.cos(2 * np.pi * df['day'] / 30)
    df['sin_dayofweek'] = np.sin(2 * np.pi * df['dayofweek'] / 7)
    df['cos_dayofweek'] = np.cos(2 * np.pi * df['dayofweek'] / 7)
    df['sin_month'] = np.sin(2 * np.pi * df['month'] / 12)
    df['cos_month'] = np.cos(2 * np.pi * df['month'] / 12)

    # drop hour, day, dayofweek, month
    df = df.drop(['hour', 'day', 'dayofweek', 'month', 'time'], axis=1)

    return df

train = time_features(train)
eval = time_features(eval)

# ShippinglineID to label encoding
le_shippingLineId = LabelEncoder()
combined_shippingline_ids = pd.concat([train['shippingLineId'], schedules['shippingLineId']]).unique()
le_shippingLineId.fit(combined_shippingline_ids)
train['shippingLineId'] = le_shippingLineId.transform(train['shippingLineId'])
eval['shippingLineId'] = le_shippingLineId.transform(eval['shippingLineId'])
schedules['shippingLineId'] = le_shippingLineId.transform(schedules['shippingLineId'])

# Use information from schedules to check which shipping lines goes to what ports
shippingline_ports = schedules[['shippingLineId', 'portId', 'portLongitude', 'portLatitude']].drop_duplicates()


# Create a dictionary mapping shippingLineId to possible port coordinates
shippingline_ports_dict = shippingline_ports.groupby('shippingLineId')[['portLongitude', 'portLatitude']].apply(lambda x: x.values.tolist()).to_dict()

display(shippingline_ports)
display(shippingline_ports_dict)
display(train.head())
display(eval.head())
# Out:
#         shippingLineId  portId  portLongitude  portLatitude
# 0                    1     379     -81.496666     31.140556
# 1                    1     351      -1.428889     50.902500
# 2                    1      98       8.554722     53.563610
# 3                    1     366     -74.028610     40.688332
# 4                    1     270     -79.879791      9.372370
# ...                ...     ...            ...           ...
# 72552                5     136       8.916389     44.404720
# 87936                0      71     -69.881111     18.475279
# 106065               0     242      -9.635833     30.423889
# 117119               1     409     -56.206669    -34.900555
# 124999               0      69      43.136944     11.601944
#
# [220 rows x 4 columns]
# {0: [[31.0272216796875, -29.88111114501953],
#   [56.74055480957031, 24.378332138061523],
#   [48.15972137451172, 29.044721603393555],
#   [-81.56444549560547, 30.38083267211914],
#   [25.029460906982422, 51.6245002746582],
#   [-76.8294448852539, 17.981666564941406],
#   [-79.92749786376953, 32.82222366333008],
#   [72.8852767944336, 18.941944122314453],
#   [-93.96111297607422, 29.843055725097656],
#   [-94.08333587646484, 30.07805633544922],
#   [-95.31916809082031, 28.9505558013916],
#   [-96.1338882446289, 19.208332061767578],
#   [121.18555450439453, 31.65833282470703],
#   [4.828332901000977, 52.413055419921875],
#   [33.64277648925781, 34.92416763305664],
#   [23.61039924621582, 37.951141357421875],
#   [3.2072219848632812, 51.336387634277344],
#   [-1.4288890361785889, 50.90250015258789],
#   [151.7705535888672, -32.907501220703125],
#   [4.299722194671631, 51.29777908325195],
#   [14.511943817138672, 35.89527893066406],
#   [-3.8077778816223145, 43.442222595214844],
#   [150.89944458007812, -34.462501525878906],
#   [144.91749572753906, -37.83277893066406],
#   [153.16944885253906, -27.38249969482422],
#   [139.74972534179688, 35.50638961791992],
#   [132.42416381835938, 34.36527633666992],
#   [8.55472183227539, 53.5636100769043],
#   [135.24082946777344, 34.684165954589844],
#   [9.963333129882812, 53.524723052978516],
#   [136.84805297851562, 35.04499816894531],
#   [-76.55889129638672, 39.23249816894531],
#   [128.62611389160156, 35.16416549682617],
#   [0.17777800559997559, 49.46694564819336],
#   [-8.731666564941406, 42.24250030517578],
#   [-61.06194305419922, 14.599444389343262],
#   [-5.816999912261963, 35.78300094604492],
#   [-61.4734992980957, 10.326499938964844],
#   [174.7711181640625, -36.836387634277344],
#   [39.6349983215332, -4.051111221313477],
#   [103.72528076171875, 1.2927780151367188],
#   [39.29916763305664, -6.834444046020508],
#   [130.90167236328125, 33.934444427490234],
#   [140.62110900878906, 36.42527770996094],
#   [7.198332786560059, 53.34611129760742],
#   [117.69999694824219, 38.983001708984375],
#   [25.636388778686523, -33.961387634277344],
#   [139.6677703857422, 35.4363899230957],
#   [32.56111145019531, -25.9727783203125],
#   [138.21694946289062, 34.61944580078125],
#   [10.303055763244629, 43.55583190917969],
#   [55.059444427490234, 24.995832443237305],
#   [-75.52166748046875, 39.71666717529297],
#   [39.16416549682617, 21.45861053466797],
#   [54.3761100769043, 24.524999618530273],
#   [48.0017204284668, 29.366300582885742],
#   [34.99279022216797, 29.519880294799805],
#   [50.20111083984375, 26.488611221313477],
#   [11.871944427490234, 57.68916702270508],
#   [115.74082946777344, -32.04750061035156],
#   [57.49361038208008, -20.148056030273438],
#   [71.55000305175781, 20.966999053955078],
#   [100.89527893066406, 13.073888778686523],
#   [121.48300170898438, 31.232999801635742],
#   [-102.1802749633789, 17.934167861938477],
#   [-63.578887939453125, 44.656944274902344],
#   [45.28300094604492, -12.800000190734863],
#   [-75.53083038330078, 10.403332710266113],
#   [-66.10221862792969, 18.456388473510742],
#   [-88.04027557373047, 30.711389541625977],
#   [129.0594482421875, 35.10944366455078],
#   [-97.87472534179688, 22.48722267150879],
#   [137.2383270263672, 34.815555572509766],
#   [166.4311065673828, -22.259721755981445],
#   [-4.4191670417785645, 36.70916748046875],
#   [-70.01889038085938, 18.420278549194336],
#   [2.164721965789795, 41.34027862548828],
#   [-61.516998291015625, 10.649999618530273],
#   [138.5124969482422, -34.79916763305664],
#   [137.30917358398438, 34.72138977050781],
#   [-17.43000030517578, 14.682222366333008],
#   [136.64944458007812, 34.95722198486328],
#   [10.735278129577637, 59.897220611572266],
#   [-97.40721893310547, 27.81277847290039],
#   [38.04999923706055, 24.066999435424805],
#   [1.222499966621399, 41.09416580200195],
#   [-81.49666595458984, 31.14055633544922],
#   [-5.399444103240967, 36.14860916137695],
#   [-2.712222099304199, 51.4988899230957],
#   [80.34111022949219, 13.263333320617676],
#   [4.298333168029785, 51.927223205566406],
#   [70.22555541992188, 23.01361083984375],
#   [121.66699981689453, 29.91699981689453],
#   [-69.88111114501953, 18.475278854370117],
#   [-9.635832786560059, 30.42388916015625],
#   [43.13694381713867, 11.601943969726562]],
#  1: [[-81.49666595458984, 31.14055633544922],
#   [-1.4288890361785889, 50.90250015258789],
#   [8.55472183227539, 53.5636100769043],
#   [-74.02861022949219, 40.688331604003906],
#   [-79.87979125976562, 9.372369766235352],
#   [-81.1258316040039, 32.11083221435547],
#   [-76.55889129638672, 39.23249816894531],
#   [3.2072219848632812, 51.336387634277344],
#   [-80.72333526611328, -0.9355559945106506],
#   [-71.61888885498047, -33.587501525878906],
#   [-70.32499694824219, -18.47305679321289],
#   [-94.81861114501953, 29.304166793823242],
#   [-77.14666748046875, -12.04527759552002],
#   [-8.731666564941406, 42.24250030517578],
#   [150.89944458007812, -34.462501525878906],
#   [-63.578887939453125, 44.656944274902344],
#   [115.74082946777344, -32.04750061035156],
#   [-76.29777526855469, 36.90194320678711],
#   [153.16944885253906, -27.38249969482422],
#   [174.7711181640625, -36.836387634277344],
#   [144.91749572753906, -37.83277893066406],
#   [4.299722194671631, 51.29777908325195],
#   [-48.51527786254883, -25.496944427490234],
#   [-43.1966667175293, -22.883056640625],
#   [-46.30083465576172, -23.968889236450195],
#   [-96.1338882446289, 19.208332061767578],
#   [-52.081668853759766, -32.05611038208008],
#   [-75.53083038330078, 10.403332710266113],
#   [126.59083557128906, 35.959720611572266],
#   [139.6677703857422, 35.4363899230957],
#   [126.61750030517578, 37.47416687011719],
#   [103.72528076171875, 1.2927780151367188],
#   [-2.712222099304199, 51.4988899230957],
#   [138.21694946289062, 34.61944580078125],
#   [128.62611389160156, 35.16416549682617],
#   [121.48300170898438, 31.232999801635742],
#   [135.24082946777344, 34.684165954589844],
#   [136.84805297851562, 35.04499816894531],
#   [166.4311065673828, -22.259721755981445],
#   [140.62277221679688, 36.4908332824707],
#   [-122.40666961669922, 47.2672233581543],
#   [-118.20111083984375, 33.7488899230957],
#   [121.65055847167969, 38.93361282348633],
#   [117.46028137207031, 39.00944519042969],
#   [-97.87472534179688, 22.48722267150879],
#   [-119.20777893066406, 34.149166107177734],
#   [11.871944427490234, 57.68916702270508],
#   [0.17777800559997559, 49.46694564819336],
#   [55.31972122192383, -20.93055534362793],
#   [-79.92749786376953, 32.82222366333008],
#   [11.699999809265137, 58.008888244628906],
#   [-3.0113890171051025, 53.4363899230957],
#   [-69.88111114501953, 18.475278854370117],
#   [-149.57139587402344, -17.531110763549805],
#   [22.216388702392578, 60.43777847290039],
#   [31.0272216796875, -29.88111114501953],
#   [27.907499313354492, -33.02527618408203],
#   [-3.8077778816223145, 43.442222595214844],
#   [2.164721965789795, 41.34027862548828],
#   [106.86055755615234, -6.105556011199951],
#   [-102.1802749633789, 17.934167861938477],
#   [100.89527893066406, 13.073888778686523],
#   [72.8852767944336, 18.941944122314453],
#   [-88.61699676513672, 15.699999809265137],
#   [-87.94416809082031, 15.833333015441895],
#   [-83.03299713134766, 10.0],
#   [119.413330078125, 34.745277404785156],
#   [1.222499966621399, 41.09416580200195],
#   [-59.00777816772461, -34.0988883972168],
#   [-74.75971984863281, 10.967222213745117],
#   [10.303055763244629, 43.55583190917969],
#   [-75.52166748046875, 39.71666717529297],
#   [121.39221954345703, 37.571109771728516],
#   [25.636388778686523, -33.961387634277344],
#   [23.61039924621582, 37.951141357421875],
#   [-70.41555786132812, -23.087778091430664],
#   [27.149999618530273, 38.41699981689453],
#   [-66.10221862792969, 18.456388473510742],
#   [13.73611068725586, 45.55694580078125],
#   [-8.835556030273438, 38.49277877807617],
#   [-56.206668853759766, -34.90055465698242]],
#  3: [[2.164721965789795, 41.34027862548828],
#   [-94.81861114501953, 29.304166793823242],
#   [-96.1338882446289, 19.208332061767578],
#   [-97.87472534179688, 22.48722267150879],
#   [8.55472183227539, 53.5636100769043],
#   [-1.4288890361785889, 50.90250015258789],
#   [3.2072219848632812, 51.336387634277344],
#   [-79.92749786376953, 32.82222366333008],
#   [-76.55889129638672, 39.23249816894531],
#   [-81.49666595458984, 31.14055633544922]],
#  5: [[23.61039924621582, 37.951141357421875],
#   [3.2072219848632812, 51.336387634277344],
#   [-0.21250000596046448, 39.64277648925781],
#   [32.56111145019531, -25.9727783203125],
#   [-8.731666564941406, 42.24250030517578],
#   [8.55472183227539, 53.5636100769043],
#   [10.303055763244629, 43.55583190917969],
#   [0.17777800559997559, 49.46694564819336],
#   [8.12527847290039, 53.529998779296875],
#   [10.735278129577637, 59.897220611572266],
#   [11.699999809265137, 58.008888244628906],
#   [13.0024995803833, 55.62555694580078],
#   [10.229722023010254, 59.73666763305664],
#   [-3.8077778816223145, 43.442222595214844],
#   [4.298333168029785, 51.927223205566406],
#   [-1.9177780151367188, 43.323612213134766],
#   [-1.4288890361785889, 50.90250015258789],
#   [11.871944427490234, 57.68916702270508],
#   [8.43416690826416, 55.46555709838867],
#   [9.963333129882812, 53.524723052978516],
#   [4.828332901000977, 52.413055419921875],
#   [-1.4452780485153198, 54.99444580078125],
#   [16.54694366455078, 68.79499816894531],
#   [-70.32499694824219, -18.47305679321289],
#   [8.916389465332031, 44.404720306396484]],
#  16: [[-74.02861022949219, 40.688331604003906],
#   [11.871944427490234, 57.68916702270508],
#   [4.299722194671631, 51.29777908325195],
#   [-76.55889129638672, 39.23249816894531],
#   [-3.0113890171051025, 53.4363899230957],
#   [9.963333129882812, 53.524723052978516],
#   [-63.578887939453125, 44.656944274902344],
#   [-76.29777526855469, 36.90194320678711]]}
#    vesselId    cog   sog  rot  heading  navstat   latitude   longitude  \
# 0        50  284.0   0.7    0       88        0 -34.743698  -57.851299
# 1       189  109.6   0.0   -6      347        1   8.894400  -79.479393
# 2       432  111.0  11.0    0      112        0  39.190651  -76.475670
# 3       110   96.4   0.0    0      142        1 -34.411888  151.020676
# 4       356  214.0  19.7    0      215        0  35.883789   -5.916360
#
#    portId  shippingLineId  portLongitude  portLatitude  sin_hour  cos_hour  \
# 0      40              23     -71.618889    -33.587502       0.0       1.0
# 1     682              15     -79.532997      8.967000       0.0       1.0
# 2     358              14     -76.558891     39.232498       0.0       1.0
# 3      18               1     150.899445    -34.462502       0.0       1.0
# 4     613              15      -5.817000     35.783001       0.0       1.0
#
#     sin_day   cos_day  sin_dayofweek  cos_dayofweek  sin_month  cos_month
# 0  0.207912  0.978148            0.0            1.0        0.5   0.866025
# 1  0.207912  0.978148            0.0            1.0        0.5   0.866025
# 2  0.207912  0.978148            0.0            1.0        0.5   0.866025
# 3  0.207912  0.978148            0.0            1.0        0.5   0.866025
# 4  0.207912  0.978148            0.0            1.0        0.5   0.866025
#    ID  vesselId  shippingLineId  sin_hour  cos_hour   sin_day   cos_day  \
# 0   0        84               1       0.0       1.0  0.994522 -0.104528
# 1   1       623              18       0.0       1.0  0.994522 -0.104528
# 2   2       596              21       0.0       1.0  0.994522 -0.104528
# 3   3       542              15       0.0       1.0  0.994522 -0.104528
# 4   4         1              25       0.0       1.0  0.994522 -0.104528
#
#    sin_dayofweek  cos_dayofweek  sin_month  cos_month
# 0       0.974928      -0.222521        0.5  -0.866025
# 1       0.974928      -0.222521        0.5  -0.866025
# 2       0.974928      -0.222521        0.5  -0.866025
# 3       0.974928      -0.222521        0.5  -0.866025
# 4       0.974928      -0.222521        0.5  -0.866025

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report, accuracy_score

# Define features and target
features_classifier = ['vesselId', 'sin_hour', 'cos_hour', 'sin_day', 'cos_day', 'sin_dayofweek', 'cos_dayofweek', 'sin_month', 'cos_month', 'shippingLineId']
target_classifier = ['portLongitude', 'portLatitude']

input_tts = train[features_classifier+target_classifier].dropna()

# Prepare training and validation data
X_train_port, X_val_port, y_train_port, y_val_port = train_test_split(input_tts[features_classifier], input_tts[target_classifier], random_state=42, test_size=0.2)

model_ports = MultiOutputRegressor(RandomForestRegressor())

# %%
model_ports.fit(X_train_port,y_train_port)

# %%
# Save model
import pickle
model_ports_csv = 'models/model_ports.sav'
pickle.dump(model_ports, open(model_ports_csv, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 import pickle
#       3 model_ports_csv = 'models/model_ports.sav'
# ----> 4 pickle.dump(model_ports, open(model_ports_csv, 'wb'))
#
# File c:\Users\avira\OneDrive - NTNU\Master EMIL\1. semester\ML\TDT4173-Gruppe-8\.venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/model_ports.sav'

# %%
# Function to find the closest valid port coordinates
def find_closest_port(predicted_coords, valid_ports):
    closest_port = min(valid_ports, key=lambda port: np.linalg.norm(np.array(port) - np.array(predicted_coords)))
    return closest_port

# Prediction function with filter
def predict_with_filter(model, data, shippingline_ports_dict):
    predictions = []
    for index, row in data.iterrows():
        shipping_line_id = row['shippingLineId']
        valid_ports = shippingline_ports_dict.get(shipping_line_id)
        
        # Get model predictions
        model_predictions = model.predict([row])[0]
        
        # Find the closest valid port coordinates
        closest_port = find_closest_port(model_predictions, valid_ports)
        
        predictions.append(closest_port)
    
    return predictions

# Example usage
predictions_port = predict_with_filter(model_ports, X_val_port, shippingline_ports_dict)

# Evaluate the model
mse = mean_squared_error(y_val_port, predictions_port)
print("Mean Squared Error:", mse)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[12], line 24
#      21     return predictions
#      23 # Example usage
# ---> 24 predictions_port = predict_with_filter(model_ports, X_val_port, shippingline_ports_dict)
#      26 # Evaluate the model
#      27 mse = mean_squared_error(y_val_port, predictions_port)
#
# Cell In[12], line 14, in predict_with_filter(model, data, shippingline_ports_dict)
#      11 valid_ports = shippingline_ports_dict.get(shipping_line_id)
#      13 # Get model predictions
# ---> 14 model_predictions = model.predict([row])[0]
#      16 # Find the closest valid port coordinates
#      17 closest_port = find_closest_port(model_predictions, valid_ports)
#
# File c:\Users\avira\OneDrive - NTNU\Master EMIL\1. semester\ML\TDT4173-Gruppe-8\.venv\Lib\site-packages\sklearn\multioutput.py:306, in _MultiOutputEstimator.predict(self, X)
#     292 def predict(self, X):
#     293     """Predict multi-output variable using model for each target variable.
#     294
#     295     Parameters
#    (...)
#     304         Note: Separate models are generated for each predictor.
#     305     """
# --> 306     check_is_fitted(self)
#     307     if not hasattr(self.estimators_[0], "predict"):
#     308         raise ValueError("The base estimator should implement a predict method")
#
# File c:\Users\avira\OneDrive - NTNU\Master EMIL\1. semester\ML\TDT4173-Gruppe-8\.venv\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This MultiOutputRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

# Function to split data for each vessel
def split_vessel_data(df, vessel_id_col='vesselId', test_size=0.2):
    train_list = []
    test_list = []
    
    for vessel_id in df[vessel_id_col].unique():
        vessel_data = df[df[vessel_id_col] == vessel_id]
        if len(vessel_data) > 1:  # Ensure there are enough samples to split
            train_data, test_data = train_test_split(vessel_data, test_size=test_size, random_state=False)
            train_list.append(train_data)
            test_list.append(test_data)
        else:
            train_list.append(vessel_data)  # If not enough samples, add all to train_list
    
    train_combined = pd.concat(train_list).reset_index(drop=True)
    test_combined = pd.concat(test_list).reset_index(drop=True)
    
    return train_combined, test_combined

# Split the data
train_split, test_split = split_vessel_data(train)

X_train = train_split[features]
y_train = train_split[target]

X_val = test_split[features]
y_val = test_split[target]

# Display the results
print('X_train:', X_train.shape)
display(X_train.head())
print('y_train:', y_train.shape)
display(y_train.head())
print('X_val:', X_val.shape)
display(X_val.head())
print('y_val:', y_val.shape)
display(y_val.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 25
#      22 # Split the data
#      23 train_split, test_split = split_vessel_data(train)
# ---> 25 X_train = train_split[features]
#      26 y_train = train_split[target]
#      28 X_val = test_split[features]
#
# NameError: name 'features' is not defined

# %% [markdown]
# ### Prep data for LSTM (scale and converd to 3D-array)

# %%
# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_val = scaler_y.transform(y_val)


timesteps = 10
# Reshape the data for LSTM (samples, timesteps, features)
# Assuming we are creating sequences of 'timesteps' for each sample
def create_sequences(X, timesteps):
    sequences = []
    for i in range(len(X) - timesteps):
        sequences.append(X[i:i + timesteps])
    return np.array(sequences)

X_train_seq = create_sequences(X_train, timesteps)
X_val_seq = create_sequences(X_val, timesteps)

# Reshape your target variables (y_train, y_val) in the same way
y_train_seq = create_sequences(y_train, timesteps)
y_val_seq = create_sequences(y_val, timesteps)

# Check the final shapes
print(X_train_seq.shape)  # Should be (number of samples, timesteps, number of features)
print(y_train_seq.shape)  # Should be (number of samples, timesteps, 2) for lat/lon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Scale data
#       2 scaler = StandardScaler()
# ----> 3 X_train = scaler.fit_transform(X_train)
#       4 X_val = scaler.transform(X_val)
#       6 scaler_y = StandardScaler()
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### Define, compile and train model

# %%
# LSTM model

def check_for_nans(generator):
    for batch in generator:
        if np.any(np.isnan(batch[0])) or np.any(np.isnan(batch[1])):
            print("Found NaNs in the data!")
            break

# Input shape
n_features = X_train_seq.shape[2]

print(n_features)

inputs = Input(shape=(None, n_features))

# LSTM layers
x = LSTM(units=64, return_sequences=True)(inputs)
x = LSTM(units=32)(x)

# Latitude and Longitude (continuous outputs)
lat_output = Dense(units=1, name='latitude')(x)
lon_output = Dense(units=1, name='longitude')(x)

# Define model
model_LSTM = Model(inputs=inputs, outputs=[lat_output, lon_output])

# Compile the model
model_LSTM.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={
        'latitude': 'mse',
        'longitude': 'mse'
    },
    metrics={
        'latitude': 'mae',
        'longitude': 'mae'
    },
    loss_weights={'latitude': 1.0, 'longitude': 1.0}
)


# Reshape target variables to match the expected shape
y_train_seq_lat = y_train_seq[:, :, 0].reshape(-1, timesteps, 1)
y_train_seq_lon = y_train_seq[:, :, 1].reshape(-1, timesteps, 1)
y_val_seq_lat = y_val_seq[:, :, 0].reshape(-1, timesteps, 1)
y_val_seq_lon = y_val_seq[:, :, 1].reshape(-1, timesteps, 1)

model_LSTM.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       7             break
#       9 # Input shape
# ---> 10 n_features = X_train_seq.shape[2]
#      12 print(n_features)
#      14 inputs = Input(shape=(None, n_features))
#
# NameError: name 'X_train_seq' is not defined

# %%
# Fit the model
model_LSTM.fit(
    x=X_train_seq,
    y={'latitude': y_train_seq_lat, 'longitude': y_train_seq_lon},
    epochs=50,
    batch_size=128,
    validation_data=(X_val_seq, {'latitude': y_val_seq_lat, 'longitude': y_val_seq_lon})
)
# Out:
# 14
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None, 14)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, None, 64)  │     20,224 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 32)        │     12,416 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ latitude (Dense)    │ (None, 1)         │         33 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ longitude (Dense)   │ (None, 1)         │         33 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 32,706 (127.76 KB)
#  Trainable params: 32,706 (127.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 230s 23ms/step - latitude_loss: 0.5907 - latitude_mse: 0.5907 - longitude_loss: 0.6908 - longitude_mse: 0.6908 - loss: 1.2816 - val_latitude_loss: 0.4903 - val_latitude_mse: 0.4903 - val_longitude_loss: 0.5635 - val_longitude_mse: 0.5634 - val_loss: 1.0538
# Epoch 2/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 198s 21ms/step - latitude_loss: 0.4721 - latitude_mse: 0.4721 - longitude_loss: 0.5516 - longitude_mse: 0.5516 - loss: 1.0237 - val_latitude_loss: 0.4783 - val_latitude_mse: 0.4783 - val_longitude_loss: 0.5480 - val_longitude_mse: 0.5480 - val_loss: 1.0262
# Epoch 3/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 92s 10ms/step - latitude_loss: 0.4560 - latitude_mse: 0.4560 - longitude_loss: 0.5344 - longitude_mse: 0.5344 - loss: 0.9904 - val_latitude_loss: 0.4639 - val_latitude_mse: 0.4639 - val_longitude_loss: 0.5351 - val_longitude_mse: 0.5351 - val_loss: 0.9990
# Epoch 4/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 155s 16ms/step - latitude_loss: 0.4489 - latitude_mse: 0.4489 - longitude_loss: 0.5269 - longitude_mse: 0.5269 - loss: 0.9758 - val_latitude_loss: 0.4600 - val_latitude_mse: 0.4600 - val_longitude_loss: 0.5286 - val_longitude_mse: 0.5285 - val_loss: 0.9886
# Epoch 5/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 213s 22ms/step - latitude_loss: 0.4447 - latitude_mse: 0.4447 - longitude_loss: 0.5219 - longitude_mse: 0.5219 - loss: 0.9666 - val_latitude_loss: 0.4569 - val_latitude_mse: 0.4570 - val_longitude_loss: 0.5253 - val_longitude_mse: 0.5252 - val_loss: 0.9822
# Epoch 6/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 214s 22ms/step - latitude_loss: 0.4423 - latitude_mse: 0.4423 - longitude_loss: 0.5201 - longitude_mse: 0.5201 - loss: 0.9624 - val_latitude_loss: 0.4545 - val_latitude_mse: 0.4545 - val_longitude_loss: 0.5216 - val_longitude_mse: 0.5216 - val_loss: 0.9761
# Epoch 7/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 206s 22ms/step - latitude_loss: 0.4415 - latitude_mse: 0.4415 - longitude_loss: 0.5173 - longitude_mse: 0.5173 - loss: 0.9588 - val_latitude_loss: 0.4535 - val_latitude_mse: 0.4535 - val_longitude_loss: 0.5197 - val_longitude_mse: 0.5196 - val_loss: 0.9731
# Epoch 8/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 201s 21ms/step - latitude_loss: 0.4396 - latitude_mse: 0.4396 - longitude_loss: 0.5142 - longitude_mse: 0.5142 - loss: 0.9538 - val_latitude_loss: 0.4550 - val_latitude_mse: 0.4550 - val_longitude_loss: 0.5187 - val_longitude_mse: 0.5186 - val_loss: 0.9736
# Epoch 9/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 160s 17ms/step - latitude_loss: 0.4381 - latitude_mse: 0.4381 - longitude_loss: 0.5130 - longitude_mse: 0.5130 - loss: 0.9511 - val_latitude_loss: 0.4521 - val_latitude_mse: 0.4521 - val_longitude_loss: 0.5177 - val_longitude_mse: 0.5176 - val_loss: 0.9697
# Epoch 10/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 141s 15ms/step - latitude_loss: 0.4373 - latitude_mse: 0.4373 - longitude_loss: 0.5110 - longitude_mse: 0.5110 - loss: 0.9483 - val_latitude_loss: 0.4505 - val_latitude_mse: 0.4506 - val_longitude_loss: 0.5155 - val_longitude_mse: 0.5155 - val_loss: 0.9660
# Epoch 11/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 131s 14ms/step - latitude_loss: 0.4357 - latitude_mse: 0.4357 - longitude_loss: 0.5121 - longitude_mse: 0.5121 - loss: 0.9478 - val_latitude_loss: 0.4494 - val_latitude_mse: 0.4494 - val_longitude_loss: 0.5145 - val_longitude_mse: 0.5144 - val_loss: 0.9638
# Epoch 12/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 140s 15ms/step - latitude_loss: 0.4352 - latitude_mse: 0.4352 - longitude_loss: 0.5090 - longitude_mse: 0.5090 - loss: 0.9442 - val_latitude_loss: 0.4508 - val_latitude_mse: 0.4509 - val_longitude_loss: 0.5144 - val_longitude_mse: 0.5144 - val_loss: 0.9652
# Epoch 13/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 151s 16ms/step - latitude_loss: 0.4345 - latitude_mse: 0.4345 - longitude_loss: 0.5089 - longitude_mse: 0.5089 - loss: 0.9434 - val_latitude_loss: 0.4481 - val_latitude_mse: 0.4481 - val_longitude_loss: 0.5127 - val_longitude_mse: 0.5127 - val_loss: 0.9608
# Epoch 14/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 148s 16ms/step - latitude_loss: 0.4330 - latitude_mse: 0.4330 - longitude_loss: 0.5065 - longitude_mse: 0.5065 - loss: 0.9394 - val_latitude_loss: 0.4469 - val_latitude_mse: 0.4469 - val_longitude_loss: 0.5124 - val_longitude_mse: 0.5124 - val_loss: 0.9593
# Epoch 15/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 145s 15ms/step - latitude_loss: 0.4324 - latitude_mse: 0.4324 - longitude_loss: 0.5085 - longitude_mse: 0.5085 - loss: 0.9409 - val_latitude_loss: 0.4468 - val_latitude_mse: 0.4468 - val_longitude_loss: 0.5118 - val_longitude_mse: 0.5117 - val_loss: 0.9585
# Epoch 16/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 148s 16ms/step - latitude_loss: 0.4341 - latitude_mse: 0.4341 - longitude_loss: 0.5068 - longitude_mse: 0.5068 - loss: 0.9409 - val_latitude_loss: 0.4459 - val_latitude_mse: 0.4459 - val_longitude_loss: 0.5109 - val_longitude_mse: 0.5108 - val_loss: 0.9567
# Epoch 17/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 141s 15ms/step - latitude_loss: 0.4325 - latitude_mse: 0.4325 - longitude_loss: 0.5072 - longitude_mse: 0.5072 - loss: 0.9396 - val_latitude_loss: 0.4454 - val_latitude_mse: 0.4454 - val_longitude_loss: 0.5105 - val_longitude_mse: 0.5105 - val_loss: 0.9559
# Epoch 18/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 142s 15ms/step - latitude_loss: 0.4316 - latitude_mse: 0.4316 - longitude_loss: 0.5078 - longitude_mse: 0.5078 - loss: 0.9395 - val_latitude_loss: 0.4457 - val_latitude_mse: 0.4457 - val_longitude_loss: 0.5106 - val_longitude_mse: 0.5105 - val_loss: 0.9562
# Epoch 19/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 157s 17ms/step - latitude_loss: 0.4311 - latitude_mse: 0.4311 - longitude_loss: 0.5064 - longitude_mse: 0.5064 - loss: 0.9374 - val_latitude_loss: 0.4448 - val_latitude_mse: 0.4448 - val_longitude_loss: 0.5103 - val_longitude_mse: 0.5102 - val_loss: 0.9551
# Epoch 20/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 183s 19ms/step - latitude_loss: 0.4301 - latitude_mse: 0.4301 - longitude_loss: 0.5059 - longitude_mse: 0.5059 - loss: 0.9360 - val_latitude_loss: 0.4443 - val_latitude_mse: 0.4443 - val_longitude_loss: 0.5098 - val_longitude_mse: 0.5098 - val_loss: 0.9541
# Epoch 21/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 151s 16ms/step - latitude_loss: 0.4308 - latitude_mse: 0.4308 - longitude_loss: 0.5058 - longitude_mse: 0.5058 - loss: 0.9365 - val_latitude_loss: 0.4517 - val_latitude_mse: 0.4517 - val_longitude_loss: 0.5145 - val_longitude_mse: 0.5145 - val_loss: 0.9661
# Epoch 22/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 122s 13ms/step - latitude_loss: 0.4302 - latitude_mse: 0.4302 - longitude_loss: 0.5050 - longitude_mse: 0.5050 - loss: 0.9352 - val_latitude_loss: 0.4441 - val_latitude_mse: 0.4441 - val_longitude_loss: 0.5092 - val_longitude_mse: 0.5091 - val_loss: 0.9532
# Epoch 23/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 146s 15ms/step - latitude_loss: 0.4309 - latitude_mse: 0.4309 - longitude_loss: 0.5054 - longitude_mse: 0.5054 - loss: 0.9364 - val_latitude_loss: 0.4437 - val_latitude_mse: 0.4437 - val_longitude_loss: 0.5090 - val_longitude_mse: 0.5089 - val_loss: 0.9526
# Epoch 24/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 128s 13ms/step - latitude_loss: 0.4297 - latitude_mse: 0.4297 - longitude_loss: 0.5040 - longitude_mse: 0.5040 - loss: 0.9338 - val_latitude_loss: 0.4433 - val_latitude_mse: 0.4433 - val_longitude_loss: 0.5085 - val_longitude_mse: 0.5085 - val_loss: 0.9518
# Epoch 25/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 128s 13ms/step - latitude_loss: 0.4300 - latitude_mse: 0.4300 - longitude_loss: 0.5059 - longitude_mse: 0.5059 - loss: 0.9359 - val_latitude_loss: 0.4430 - val_latitude_mse: 0.4430 - val_longitude_loss: 0.5084 - val_longitude_mse: 0.5083 - val_loss: 0.9513
# Epoch 26/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4297 - latitude_mse: 0.4297 - longitude_loss: 0.5043 - longitude_mse: 0.5043 - loss: 0.9339 - val_latitude_loss: 0.4429 - val_latitude_mse: 0.4429 - val_longitude_loss: 0.5084 - val_longitude_mse: 0.5084 - val_loss: 0.9512
# Epoch 27/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 121s 13ms/step - latitude_loss: 0.4293 - latitude_mse: 0.4293 - longitude_loss: 0.5049 - longitude_mse: 0.5049 - loss: 0.9342 - val_latitude_loss: 0.4423 - val_latitude_mse: 0.4423 - val_longitude_loss: 0.5077 - val_longitude_mse: 0.5077 - val_loss: 0.9500
# Epoch 28/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4299 - latitude_mse: 0.4299 - longitude_loss: 0.5055 - longitude_mse: 0.5055 - loss: 0.9354 - val_latitude_loss: 0.4427 - val_latitude_mse: 0.4427 - val_longitude_loss: 0.5080 - val_longitude_mse: 0.5079 - val_loss: 0.9507
# Epoch 29/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 117s 12ms/step - latitude_loss: 0.4285 - latitude_mse: 0.4285 - longitude_loss: 0.5045 - longitude_mse: 0.5045 - loss: 0.9330 - val_latitude_loss: 0.4422 - val_latitude_mse: 0.4422 - val_longitude_loss: 0.5078 - val_longitude_mse: 0.5077 - val_loss: 0.9499
# Epoch 30/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 119s 12ms/step - latitude_loss: 0.4287 - latitude_mse: 0.4287 - longitude_loss: 0.5030 - longitude_mse: 0.5030 - loss: 0.9317 - val_latitude_loss: 0.4419 - val_latitude_mse: 0.4419 - val_longitude_loss: 0.5079 - val_longitude_mse: 0.5078 - val_loss: 0.9497
# Epoch 31/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 116s 12ms/step - latitude_loss: 0.4288 - latitude_mse: 0.4288 - longitude_loss: 0.5042 - longitude_mse: 0.5042 - loss: 0.9330 - val_latitude_loss: 0.4416 - val_latitude_mse: 0.4416 - val_longitude_loss: 0.5075 - val_longitude_mse: 0.5075 - val_loss: 0.9491
# Epoch 32/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 116s 12ms/step - latitude_loss: 0.4284 - latitude_mse: 0.4284 - longitude_loss: 0.5038 - longitude_mse: 0.5038 - loss: 0.9323 - val_latitude_loss: 0.4418 - val_latitude_mse: 0.4418 - val_longitude_loss: 0.5072 - val_longitude_mse: 0.5071 - val_loss: 0.9489
# Epoch 33/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 118s 12ms/step - latitude_loss: 0.4279 - latitude_mse: 0.4279 - longitude_loss: 0.5025 - longitude_mse: 0.5025 - loss: 0.9304 - val_latitude_loss: 0.4415 - val_latitude_mse: 0.4416 - val_longitude_loss: 0.5072 - val_longitude_mse: 0.5072 - val_loss: 0.9487
# Epoch 34/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 128s 14ms/step - latitude_loss: 0.4284 - latitude_mse: 0.4284 - longitude_loss: 0.5043 - longitude_mse: 0.5043 - loss: 0.9327 - val_latitude_loss: 0.4414 - val_latitude_mse: 0.4414 - val_longitude_loss: 0.5070 - val_longitude_mse: 0.5070 - val_loss: 0.9484
# Epoch 35/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 122s 13ms/step - latitude_loss: 0.4288 - latitude_mse: 0.4288 - longitude_loss: 0.5036 - longitude_mse: 0.5036 - loss: 0.9325 - val_latitude_loss: 0.4421 - val_latitude_mse: 0.4421 - val_longitude_loss: 0.5073 - val_longitude_mse: 0.5072 - val_loss: 0.9494
# Epoch 36/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 121s 13ms/step - latitude_loss: 0.4273 - latitude_mse: 0.4273 - longitude_loss: 0.5045 - longitude_mse: 0.5045 - loss: 0.9318 - val_latitude_loss: 0.4415 - val_latitude_mse: 0.4416 - val_longitude_loss: 0.5068 - val_longitude_mse: 0.5068 - val_loss: 0.9483
# Epoch 37/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 118s 12ms/step - latitude_loss: 0.4282 - latitude_mse: 0.4282 - longitude_loss: 0.5039 - longitude_mse: 0.5039 - loss: 0.9321 - val_latitude_loss: 0.4408 - val_latitude_mse: 0.4408 - val_longitude_loss: 0.5066 - val_longitude_mse: 0.5065 - val_loss: 0.9474
# Epoch 38/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 117s 12ms/step - latitude_loss: 0.4274 - latitude_mse: 0.4274 - longitude_loss: 0.5031 - longitude_mse: 0.5031 - loss: 0.9305 - val_latitude_loss: 0.4412 - val_latitude_mse: 0.4412 - val_longitude_loss: 0.5068 - val_longitude_mse: 0.5067 - val_loss: 0.9479
# Epoch 39/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 119s 12ms/step - latitude_loss: 0.4272 - latitude_mse: 0.4272 - longitude_loss: 0.5024 - longitude_mse: 0.5024 - loss: 0.9296 - val_latitude_loss: 0.4404 - val_latitude_mse: 0.4404 - val_longitude_loss: 0.5064 - val_longitude_mse: 0.5063 - val_loss: 0.9467
# Epoch 40/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 127s 13ms/step - latitude_loss: 0.4276 - latitude_mse: 0.4276 - longitude_loss: 0.5028 - longitude_mse: 0.5028 - loss: 0.9304 - val_latitude_loss: 0.4411 - val_latitude_mse: 0.4411 - val_longitude_loss: 0.5064 - val_longitude_mse: 0.5063 - val_loss: 0.9474
# Epoch 41/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 125s 13ms/step - latitude_loss: 0.4279 - latitude_mse: 0.4279 - longitude_loss: 0.5028 - longitude_mse: 0.5028 - loss: 0.9308 - val_latitude_loss: 0.4405 - val_latitude_mse: 0.4405 - val_longitude_loss: 0.5063 - val_longitude_mse: 0.5062 - val_loss: 0.9467
# Epoch 42/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 117s 12ms/step - latitude_loss: 0.4280 - latitude_mse: 0.4280 - longitude_loss: 0.5033 - longitude_mse: 0.5033 - loss: 0.9313 - val_latitude_loss: 0.4403 - val_latitude_mse: 0.4403 - val_longitude_loss: 0.5061 - val_longitude_mse: 0.5060 - val_loss: 0.9463
# Epoch 43/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 122s 13ms/step - latitude_loss: 0.4273 - latitude_mse: 0.4273 - longitude_loss: 0.5022 - longitude_mse: 0.5022 - loss: 0.9296 - val_latitude_loss: 0.4401 - val_latitude_mse: 0.4401 - val_longitude_loss: 0.5059 - val_longitude_mse: 0.5058 - val_loss: 0.9459
# Epoch 44/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 129s 14ms/step - latitude_loss: 0.4283 - latitude_mse: 0.4283 - longitude_loss: 0.5038 - longitude_mse: 0.5038 - loss: 0.9320 - val_latitude_loss: 0.4402 - val_latitude_mse: 0.4402 - val_longitude_loss: 0.5057 - val_longitude_mse: 0.5057 - val_loss: 0.9458
# Epoch 45/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4272 - latitude_mse: 0.4272 - longitude_loss: 0.5023 - longitude_mse: 0.5023 - loss: 0.9295 - val_latitude_loss: 0.4400 - val_latitude_mse: 0.4400 - val_longitude_loss: 0.5059 - val_longitude_mse: 0.5058 - val_loss: 0.9459
# Epoch 46/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 119s 13ms/step - latitude_loss: 0.4272 - latitude_mse: 0.4272 - longitude_loss: 0.5025 - longitude_mse: 0.5025 - loss: 0.9297 - val_latitude_loss: 0.4399 - val_latitude_mse: 0.4399 - val_longitude_loss: 0.5058 - val_longitude_mse: 0.5057 - val_loss: 0.9456
# Epoch 47/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4265 - latitude_mse: 0.4265 - longitude_loss: 0.5038 - longitude_mse: 0.5038 - loss: 0.9303 - val_latitude_loss: 0.4398 - val_latitude_mse: 0.4398 - val_longitude_loss: 0.5056 - val_longitude_mse: 0.5055 - val_loss: 0.9453
# Epoch 48/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4263 - latitude_mse: 0.4263 - longitude_loss: 0.5029 - longitude_mse: 0.5029 - loss: 0.9293 - val_latitude_loss: 0.4396 - val_latitude_mse: 0.4397 - val_longitude_loss: 0.5054 - val_longitude_mse: 0.5054 - val_loss: 0.9450
# Epoch 49/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 122s 13ms/step - latitude_loss: 0.4278 - latitude_mse: 0.4278 - longitude_loss: 0.5033 - longitude_mse: 0.5033 - loss: 0.9311 - val_latitude_loss: 0.4396 - val_latitude_mse: 0.4396 - val_longitude_loss: 0.5053 - val_longitude_mse: 0.5053 - val_loss: 0.9449
# Epoch 50/50
# 9501/9501 ━━━━━━━━━━━━━━━━━━━━ 120s 13ms/step - latitude_loss: 0.4267 - latitude_mse: 0.4267 - longitude_loss: 0.5017 - longitude_mse: 0.5017 - loss: 0.9283 - val_latitude_loss: 0.4396 - val_latitude_mse: 0.4396 - val_longitude_loss: 0.5054 - val_longitude_mse: 0.5053 - val_loss: 0.9449

# %% [markdown]
# ### Save model

# %%
# Save the model
model_LSTM.save('lstm_model_2.keras')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Save the model
# ----> 2 model_LSTM.save('lstm_model_2.keras')
#
# NameError: name 'model_LSTM' is not defined

# %% [markdown]
# ### Evaluate model

# %%
# Evaluate the model on validation data
val_loss, val_lat_mae, val_lon_mae = model_LSTM.evaluate(X_val_seq, {'latitude': y_val_seq_lat, 'longitude': y_val_seq_lon})

print(f"Validation Loss: {val_loss}")
print(f"Validation Latitude MAE: {val_lat_mae}")
print(f"Validation Longitude MAE: {val_lon_mae}")

# Make predictions on the validation set
y_val_pred = model_LSTM.predict(X_val_seq)
y_val_pred_lat = y_val_pred[0].reshape(-1, 1)
y_val_pred_lon = y_val_pred[1].reshape(-1, 1)

# Inverse transform the predictions
y_val_pred = np.concatenate([y_val_pred_lat, y_val_pred_lon], axis=1)
y_val_pred = scaler_y.inverse_transform(y_val_pred)

# Calculate evaluation metrics
mse = mean_squared_error(y_val, y_val_pred)
mae = np.mean(np.abs(y_val - y_val_pred), axis=0)

print(f"Validation Mean Squared Error: {mse}")
print(f"Validation Mean Absolute Error: {mae}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Evaluate the model on validation data
# ----> 2 val_loss, val_lat_mae, val_lon_mae = model_LSTM.evaluate(X_val_seq, {'latitude': y_val_seq_lat, 'longitude': y_val_seq_lon})
#       4 print(f"Validation Loss: {val_loss}")
#       5 print(f"Validation Latitude MAE: {val_lat_mae}")
#
# NameError: name 'model_LSTM' is not defined

# %% [markdown]
# ### Predict the future

# %%
# predict on eval data
X_eval = eval[features]
X_eval = scaler.transform(X_eval)  # Ensure the correct columns are selected
X_eval = create_sequences(X_eval, timesteps)

# import the model from keras
from tensorflow.keras.models import load_model

# Load the model
model_LSTM = load_model('lstm_model_2.keras')

# Make predictions
y_eval_pred = model_LSTM.predict(X_eval)
y_eval_pred_lat = y_eval_pred[0].reshape(-1, 1)
y_eval_pred_lon = y_eval_pred[1].reshape(-1, 1)

display(y_eval_pred_lat)
display(y_eval_pred_lon)

# Inverse transform the predictions
y_eval_pred = np.concatenate([y_eval_pred_lat, y_eval_pred_lon], axis=1)
y_eval_pred = scaler_y.inverse_transform(y_eval_pred)

# Fill missing values with the first available prediction for both columns
first_value_fill = np.tile(y_eval_pred[0], (10, 1))  # Shape will be (10, 2)

# Concatenate the filled values with the actual predictions
predictions_filled = np.vstack([first_value_fill, y_eval_pred])


# Save the predictions
eval['latitude_predicted'] = predictions_filled[:, 0]
print(eval['latitude_predicted'])
eval['longitude_predicted'] = predictions_filled[:, 1]
eval[['ID', 'longitude_predicted', 'latitude_predicted']].to_csv('data/ais_eval_pred.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # predict on eval data
# ----> 2 X_eval = eval[features]
#       3 X_eval = scaler.transform(X_eval)  # Ensure the correct columns are selected
#       4 X_eval = create_sequences(X_eval, timesteps)
#
# NameError: name 'features' is not defined

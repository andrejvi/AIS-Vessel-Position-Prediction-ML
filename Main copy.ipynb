# %% [markdown]
# # AIS Trajectory

# %% [markdown]
# ### Importere biblioteker

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
import xgboost as xgb

import matplotlib as plt

# split sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Importer data

# %%
train_df = pd.read_csv('data/ais_train.csv', sep='|')
test_df = pd.read_csv('data/ais_test.csv')

ports_df = pd.read_csv('data/ports.csv', sep='|')  
schedule_df = pd.read_csv('data/schedules_to_may_2024.csv', sep='|')
vessels_df = pd.read_csv('data/vessels.csv', sep='|')

# rename longitude and latitude in ports
ports_df = ports_df.rename(columns={'longitude': 'port_longitude', 'latitude': 'port_latitude'})

# merge vessel and train data
train_df = pd.merge(train_df, vessels_df, on='vesselId', how='left')
test_df = pd.merge(test_df, vessels_df, on='vesselId', how='left')

# Drop columns that are not useful |"NT"|"depth"|"draft"|"enginePower"|"freshWater"|"fuel"|"homePort"|"maxHeight"|"maxSpeed"|"maxWidth"|"rampCapacity"|
train_df = train_df.drop(['NT', 'depth', 'draft', 'enginePower', 'freshWater', 'fuel', 'homePort', 'maxHeight', 'maxSpeed', 'maxWidth', 'rampCapacity'], axis=1)
test_df = test_df.drop(['NT', 'depth', 'draft', 'enginePower', 'freshWater', 'fuel', 'homePort', 'maxHeight', 'maxSpeed', 'maxWidth', 'rampCapacity'], axis=1)
                       
# Fill missing values in test data
test_df['DWT'] = test_df['DWT'].fillna(test_df['DWT'].mean())
test_df['vesselType'] = test_df['vesselType'].fillna(test_df['vesselType'].mode()[0])
test_df['breadth'] = test_df['breadth'].fillna(test_df['breadth'].mean())

#vessel0 = train_df['vesselId'][0]
original_train_df = train_df.copy(deep = True)
original_test_df = test_df.copy(deep = True)

display(train_df.head())
display(test_df.head())

display(schedule_df.head())
# Out:
#                   time    cog   sog  rot  heading  navstat       etaRaw  \
# 0  2024-01-01 00:00:25  284.0   0.7    0       88        0  01-09 23:00
# 1  2024-01-01 00:00:36  109.6   0.0   -6      347        1  12-29 20:00
# 2  2024-01-01 00:01:45  111.0  11.0    0      112        0  01-02 09:00
# 3  2024-01-01 00:03:11   96.4   0.0    0      142        1  12-31 20:00
# 4  2024-01-01 00:03:51  214.0  19.7    0      215        0  01-25 12:00
#
#    latitude  longitude                  vesselId                    portId  \
# 0 -34.74370  -57.85130  61e9f3a8b937134a3c4bfdf7  61d371c43aeaecc07011a37f
# 1   8.89440  -79.47939  61e9f3d4b937134a3c4bff1f  634c4de270937fc01c3a7689
# 2  39.19065  -76.47567  61e9f436b937134a3c4c0131  61d3847bb7b7526e1adf3d19
# 3 -34.41189  151.02067  61e9f3b4b937134a3c4bfe77  61d36f770a1807568ff9a126
# 4  35.88379   -5.91636  61e9f41bb937134a3c4c0087  634c4de270937fc01c3a74f3
#
#              shippingLineId   CEU      DWT     GT  vesselType  breadth  \
# 0  61ec65aea8cafc0e93f0e900  6500  21214.0  57718        83.0    32.00
# 1  61be24564ea00ae59d0fe37a  5174  18878.0  59583        83.0    32.26
# 2  61be24564ea00ae59d0fe379  6402  18383.0  59217        83.0    32.00
# 3  61a8e672f9cba188601e84ac  5849  15199.0  55598        83.0    32.00
# 4  61be24564ea00ae59d0fe37a  5219  18833.0  58939        83.0    32.20
#
#    length  yearBuilt
# 0  199.00       2004
# 1  199.97       2012
# 2  199.00       2005
# 3  199.00       1995
# 4  199.95       2010
#    ID                  vesselId                 time  scaling_factor  \
# 0   0  61e9f3aeb937134a3c4bfe3d  2024-05-08 00:03:16             0.3
# 1   1  61e9f473b937134a3c4c02df  2024-05-08 00:06:17             0.3
# 2   2  61e9f469b937134a3c4c029b  2024-05-08 00:10:02             0.3
# 3   3  61e9f45bb937134a3c4c0221  2024-05-08 00:10:34             0.3
# 4   4  61e9f38eb937134a3c4bfd8d  2024-05-08 00:12:27             0.3
#
#              shippingLineId   CEU      DWT     GT  vesselType  breadth  \
# 0  61a8e672f9cba188601e84ac  7934  31143.0  74255        83.0     32.0
# 1  61be24574ea00ae59d0fe388  2500  13238.0   9984        14.0     20.0
# 2  61ec6303a8cafc0e93f0e8f3  1400   7150.0  25995        21.0     27.0
# 3  61be24564ea00ae59d0fe37a  5007  13951.0  45959        83.0     30.2
# 4  61ec94f1a8cafc0e93f0e92a  4902  12325.0  46800        83.0     31.0
#
#    length  yearBuilt
# 0   230.0       2011
# 1   124.0       2012
# 2   186.0       2003
# 3   183.0       2011
# 4   182.0       2006
#                    vesselId            shippingLineId  \
# 0  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 1  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 2  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 3  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
# 4  61e9f3b1b937134a3c4bfe53  61a8e672f9cba188601e84ac
#
#              shippingLineName                arrivalDate  \
# 0  Wallenius Wilhelmsen Ocean  2023-10-02 00:00:00+00:00
# 1  Wallenius Wilhelmsen Ocean  2023-10-27 00:00:00+00:00
# 2  Wallenius Wilhelmsen Ocean  2023-10-19 00:00:00+00:00
# 3  Wallenius Wilhelmsen Ocean  2023-10-09 00:00:00+00:00
# 4  Wallenius Wilhelmsen Ocean  2023-09-25 00:00:00+00:00
#
#                  sailingDate                           portName  \
# 0  2023-10-03 00:00:00+00:00                  Port of Brunswick
# 1  2023-10-27 00:00:00+00:00                Port of Southampton
# 2  2023-10-20 00:00:00+00:00                Port of Bremerhaven
# 3  2023-10-10 00:00:00+00:00                   Port of New York
# 4  2023-09-26 00:00:00+00:00  Manzanillo International Terminal
#
#                      portId  portLatitude  portLongitude
# 0  61d38499b7b7526e1adf3d54     31.140556     -81.496667
# 1  61d3832bb7b7526e1adf3b63     50.902500      -1.428889
# 2  61d375e793c6feb83e5eb3e2     53.563611       8.554722
# 3  61d38481b7b7526e1adf3d23     40.688333     -74.028611
# 4  61d37d0199db2ccf7339eee1      9.372370     -79.879790

# %% [markdown]
# ### Pre-prosessering

# %%
# Label encode the vesselId
le_vesselId = LabelEncoder()
le_vesselId.fit(pd.concat([train_df['vesselId'], vessels_df['vesselId']]))
train_df['vesselId'] = le_vesselId.transform(train_df['vesselId'])
test_df['vesselId'] = le_vesselId.transform(test_df['vesselId'])
vessels_df['vesselId'] = le_vesselId.transform(vessels_df['vesselId'])

# Navstat 0 and 8 means the vessel is moving
#train_df['Moored'] = train_df['navstat'].apply(lambda x: False if x in [0, 8] else True)
#train_df = train_df.drop(columns=['navstat'])

# merge port data with train data
train_df = pd.merge(train_df, ports_df, how='left', left_on='portId', right_on='portId')

# Fill missing values in train data
train_df['port_longitude'] = train_df['port_longitude'].fillna(train_df['port_longitude'].mean())
train_df['port_latitude'] = train_df['port_latitude'].fillna(train_df['port_latitude'].mean())


# Convert timestamps to datetime
train_df['time'] = pd.to_datetime(train_df['time'])
test_df['time'] = pd.to_datetime(test_df['time'])

display(train_df)
display(test_df)
# Out:
#                        time    cog   sog  rot  heading  navstat       etaRaw  \
# 0       2024-01-01 00:00:25  284.0   0.7    0       88        0  01-09 23:00
# 1       2024-01-01 00:00:36  109.6   0.0   -6      347        1  12-29 20:00
# 2       2024-01-01 00:01:45  111.0  11.0    0      112        0  01-02 09:00
# 3       2024-01-01 00:03:11   96.4   0.0    0      142        1  12-31 20:00
# 4       2024-01-01 00:03:51  214.0  19.7    0      215        0  01-25 12:00
# ...                     ...    ...   ...  ...      ...      ...          ...
# 1522060 2024-05-07 23:59:07  359.1  13.4    0        1        0  05-08 05:00
# 1522061 2024-05-07 23:59:08   12.3  17.1    0       13        0  05-10 03:00
# 1522062 2024-05-07 23:59:08  269.8  14.9   -1      270        0  05-15 23:00
# 1522063 2024-05-07 23:59:08    8.0  18.7    0        6        0  05-08 12:45
# 1522064 2024-05-07 23:59:08  336.0  14.3    5      337        0  05-07 23:00
#
#          latitude  longitude  vesselId  ... breadth  length  yearBuilt  \
# 0       -34.74370  -57.85130        51  ...   32.00  199.00       2004
# 1         8.89440  -79.47939       198  ...   32.26  199.97       2012
# 2        39.19065  -76.47567       450  ...   32.00  199.00       2005
# 3       -34.41189  151.02067       114  ...   32.00  199.00       1995
# 4        35.88379   -5.91636       370  ...   32.20  199.95       2010
# ...           ...        ...       ...  ...     ...     ...        ...
# 1522060  52.19131   -5.82223       705  ...   25.00  182.00       2000
# 1522061  38.96142  -12.00502        89  ...   32.00  199.00       2009
# 1522062  49.71372   -5.22042       477  ...   38.00  199.96       2017
# 1522063  38.27895   10.78280       619  ...   27.00  186.00       2003
# 1522064  38.98635  -75.13275       660  ...   32.00  200.00       2011
#
#                            name          portLocation  port_longitude  \
# 0            Puerto San Antonio           San Antonio      -71.618889
# 1             Panamá, Ciudad de     Panamá, Ciudad de      -79.533000
# 2             Port of Baltimore             Baltimore      -76.558889
# 3           Port of Port Kembla           Port Kembla      150.899444
# 4                       Tangier               Tangier       -5.817000
# ...                         ...                   ...             ...
# 1522060    Waterford City Quays  Waterford City Quays       -7.100000
# 1522061                 Cascais               Cascais       -9.417000
# 1522062              Porthleven            Porthleven       -5.317000
# 1522063   Port of Civitavecchia         Civitavecchia       11.780833
# 1522064  The Port of Wilmington            Wilmington      -75.521667
#
#          port_latitude  UN_LOCODE     countryName ISO
# 0           -33.587500      CLSAI           Chile  CL
# 1             8.967000      PAPTY          Panama  PA
# 2            39.232500      USBAL   United States  US
# 3           -34.462500      AUPKL       Australia  AU
# 4            35.783000      MATNG         Morocco  MA
# ...                ...        ...             ...  ..
# 1522060      52.250000      IEWCQ         Ireland  IE
# 1522061      38.700000      PTCAS        Portugal  PT
# 1522062      50.083000      GBPLV  United Kingdom  GB
# 1522063      42.098889      ITCVV           Italy  IT
# 1522064      39.716667      USILG   United States  US
#
# [1522065 rows x 26 columns]
#           ID  vesselId                time  scaling_factor  \
# 0          0        86 2024-05-08 00:03:16             0.3
# 1          1       646 2024-05-08 00:06:17             0.3
# 2          2       619 2024-05-08 00:10:02             0.3
# 3          3       562 2024-05-08 00:10:34             0.3
# 4          4         1 2024-05-08 00:12:27             0.3
# ...      ...       ...                 ...             ...
# 51734  51734        49 2024-05-12 23:59:58             0.1
# 51735  51735       114 2024-05-12 23:59:58             0.1
# 51736  51736       633 2024-05-12 23:59:58             0.1
# 51737  51737       595 2024-05-12 23:59:58             0.1
# 51738  51738        84 2024-05-12 23:59:58             0.1
#
#                  shippingLineId   CEU      DWT     GT  vesselType  breadth  \
# 0      61a8e672f9cba188601e84ac  7934  31143.0  74255        83.0    32.00
# 1      61be24574ea00ae59d0fe388  2500  13238.0   9984        14.0    20.00
# 2      61ec6303a8cafc0e93f0e8f3  1400   7150.0  25995        21.0    27.00
# 3      61be24564ea00ae59d0fe37a  5007  13951.0  45959        83.0    30.20
# 4      61ec94f1a8cafc0e93f0e92a  4902  12325.0  46800        83.0    31.00
# ...                         ...   ...      ...    ...         ...      ...
# 51734  61a8e672f9cba188601e84ab  6000  19670.0  59705        83.0    32.00
# 51735  61a8e672f9cba188601e84ac  5849  15199.0  55598        83.0    32.00
# 51736  61a8e673f9cba188601e84b9  6178  18770.0  59516        83.0    32.26
# 51737  61ec643ca8cafc0e93f0e8f9   840   9653.0  45923        21.0    30.00
# 51738  61a8e672f9cba188601e84ac  7620  30386.0  71583        83.0    32.00
#
#        length  yearBuilt
# 0      230.00       2011
# 1      124.00       2012
# 2      186.00       2003
# 3      183.00       2011
# 4      182.00       2006
# ...       ...        ...
# 51734  199.00       2006
# 51735  199.00       1995
# 51736  199.97       2015
# 51737  218.00       2006
# 51738  227.00       2008
#
# [51739 rows x 12 columns]

# %% [markdown]
# ### Feature engineering

# %%
def convert_time_to_features(df):
    df['minute'] = df['time'].dt.minute
    df['hour'] = df['time'].dt.hour
    df['weekday'] = df['time'].dt.weekday
    df['month'] = df['time'].dt.month
    df['day'] = df['time'].dt.day

    df['time'] = df['time'].astype(int) / 10**9
    
    # Add sinusoidal features for seasonality
    df['sin_minute'] = np.sin(2 * np.pi * df['minute'] / 60)
    df['cos_minute'] = np.cos(2 * np.pi * df['minute'] / 60)
    df['sin_hour'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['cos_hour'] = np.cos(2 * np.pi * df['hour'] / 24)
    df['sin_weekday'] = np.sin(2 * np.pi * df['weekday'] / 7)
    df['cos_weekday'] = np.cos(2 * np.pi * df['weekday'] / 7)
    df['sin_month'] = np.sin(2 * np.pi * df['month'] / 12)
    df['cos_month'] = np.cos(2 * np.pi * df['month'] / 12)
    df['sin_day'] = np.sin(2 * np.pi * df['day'] / 31)
    df['cos_day'] = np.cos(2 * np.pi * df['day'] / 31)
    
    df = df.drop(columns=['hour', 'weekday', 'month', 'day', 'minute'])
    return df

# Apply the function to train_df and test_df
train_df = convert_time_to_features(train_df)
test_df = convert_time_to_features(test_df)


display(train_df)
display(test_df)
# Out:
#                  time    cog   sog  rot  heading  navstat       etaRaw  \
# 0        1.704067e+09  284.0   0.7    0       88        0  01-09 23:00
# 1        1.704067e+09  109.6   0.0   -6      347        1  12-29 20:00
# 2        1.704067e+09  111.0  11.0    0      112        0  01-02 09:00
# 3        1.704067e+09   96.4   0.0    0      142        1  12-31 20:00
# 4        1.704067e+09  214.0  19.7    0      215        0  01-25 12:00
# ...               ...    ...   ...  ...      ...      ...          ...
# 1522060  1.715126e+09  359.1  13.4    0        1        0  05-08 05:00
# 1522061  1.715126e+09   12.3  17.1    0       13        0  05-10 03:00
# 1522062  1.715126e+09  269.8  14.9   -1      270        0  05-15 23:00
# 1522063  1.715126e+09    8.0  18.7    0        6        0  05-08 12:45
# 1522064  1.715126e+09  336.0  14.3    5      337        0  05-07 23:00
#
#          latitude  longitude  vesselId  ... sin_minute cos_minute  sin_hour  \
# 0       -34.74370  -57.85130        51  ...   0.000000   1.000000  0.000000
# 1         8.89440  -79.47939       198  ...   0.000000   1.000000  0.000000
# 2        39.19065  -76.47567       450  ...   0.104528   0.994522  0.000000
# 3       -34.41189  151.02067       114  ...   0.309017   0.951057  0.000000
# 4        35.88379   -5.91636       370  ...   0.309017   0.951057  0.000000
# ...           ...        ...       ...  ...        ...        ...       ...
# 1522060  52.19131   -5.82223       705  ...  -0.104528   0.994522 -0.258819
# 1522061  38.96142  -12.00502        89  ...  -0.104528   0.994522 -0.258819
# 1522062  49.71372   -5.22042       477  ...  -0.104528   0.994522 -0.258819
# 1522063  38.27895   10.78280       619  ...  -0.104528   0.994522 -0.258819
# 1522064  38.98635  -75.13275       660  ...  -0.104528   0.994522 -0.258819
#
#          cos_hour  sin_weekday  cos_weekday  sin_month  cos_month   sin_day  \
# 0        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 1        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 2        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 3        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 4        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# ...           ...          ...          ...        ...        ...       ...
# 1522060  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522061  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522062  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522063  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522064  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
#
#           cos_day
# 0        0.979530
# 1        0.979530
# 2        0.979530
# 3        0.979530
# 4        0.979530
# ...           ...
# 1522060  0.151428
# 1522061  0.151428
# 1522062  0.151428
# 1522063  0.151428
# 1522064  0.151428
#
# [1522065 rows x 36 columns]
#           ID  vesselId          time  scaling_factor  \
# 0          0        86  1.715127e+09             0.3
# 1          1       646  1.715127e+09             0.3
# 2          2       619  1.715127e+09             0.3
# 3          3       562  1.715127e+09             0.3
# 4          4         1  1.715127e+09             0.3
# ...      ...       ...           ...             ...
# 51734  51734        49  1.715558e+09             0.1
# 51735  51735       114  1.715558e+09             0.1
# 51736  51736       633  1.715558e+09             0.1
# 51737  51737       595  1.715558e+09             0.1
# 51738  51738        84  1.715558e+09             0.1
#
#                  shippingLineId   CEU      DWT     GT  vesselType  breadth  \
# 0      61a8e672f9cba188601e84ac  7934  31143.0  74255        83.0    32.00
# 1      61be24574ea00ae59d0fe388  2500  13238.0   9984        14.0    20.00
# 2      61ec6303a8cafc0e93f0e8f3  1400   7150.0  25995        21.0    27.00
# 3      61be24564ea00ae59d0fe37a  5007  13951.0  45959        83.0    30.20
# 4      61ec94f1a8cafc0e93f0e92a  4902  12325.0  46800        83.0    31.00
# ...                         ...   ...      ...    ...         ...      ...
# 51734  61a8e672f9cba188601e84ab  6000  19670.0  59705        83.0    32.00
# 51735  61a8e672f9cba188601e84ac  5849  15199.0  55598        83.0    32.00
# 51736  61a8e673f9cba188601e84b9  6178  18770.0  59516        83.0    32.26
# 51737  61ec643ca8cafc0e93f0e8f9   840   9653.0  45923        21.0    30.00
# 51738  61a8e672f9cba188601e84ac  7620  30386.0  71583        83.0    32.00
#
#        ...  sin_minute  cos_minute  sin_hour  cos_hour  sin_weekday  \
# 0      ...    0.309017    0.951057  0.000000  1.000000     0.974928
# 1      ...    0.587785    0.809017  0.000000  1.000000     0.974928
# 2      ...    0.866025    0.500000  0.000000  1.000000     0.974928
# 3      ...    0.866025    0.500000  0.000000  1.000000     0.974928
# 4      ...    0.951057    0.309017  0.000000  1.000000     0.974928
# ...    ...         ...         ...       ...       ...          ...
# 51734  ...   -0.104528    0.994522 -0.258819  0.965926    -0.781831
# 51735  ...   -0.104528    0.994522 -0.258819  0.965926    -0.781831
# 51736  ...   -0.104528    0.994522 -0.258819  0.965926    -0.781831
# 51737  ...   -0.104528    0.994522 -0.258819  0.965926    -0.781831
# 51738  ...   -0.104528    0.994522 -0.258819  0.965926    -0.781831
#
#        cos_weekday  sin_month  cos_month   sin_day   cos_day
# 0        -0.222521        0.5  -0.866025  0.998717 -0.050649
# 1        -0.222521        0.5  -0.866025  0.998717 -0.050649
# 2        -0.222521        0.5  -0.866025  0.998717 -0.050649
# 3        -0.222521        0.5  -0.866025  0.998717 -0.050649
# 4        -0.222521        0.5  -0.866025  0.998717 -0.050649
# ...            ...        ...        ...       ...       ...
# 51734     0.623490        0.5  -0.866025  0.651372 -0.758758
# 51735     0.623490        0.5  -0.866025  0.651372 -0.758758
# 51736     0.623490        0.5  -0.866025  0.651372 -0.758758
# 51737     0.623490        0.5  -0.866025  0.651372 -0.758758
# 51738     0.623490        0.5  -0.866025  0.651372 -0.758758
#
# [51739 rows x 22 columns]

# %% [markdown]
# ### Predict portId

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from tqdm import tqdm

# Predict the port_longitude and port_latitude for each vessel in testset
# Define features and target
features_port = ['vesselId', 'sin_minute', 'cos_minute', 'sin_hour', 'cos_hour', 'sin_weekday', 'cos_weekday', 'sin_month', 'cos_month', 'time', 'CEU', 'DWT', 'GT', 'vesselType', 'breadth', 'length', 'yearBuilt']
target_port = ['port_longitude', 'port_latitude']

# Get unique vessel IDs
unique_vessels = train_df['vesselId'].unique()

# Initialize a dictionary to store models for each vessel
vessel_models = {}

# Loop through each vessel and train a model
for vessel_id in tqdm(unique_vessels, desc="Training models for each vessel"):
    # Filter the data for the current vessel
    vessel_train_df = train_df[train_df['vesselId'] == vessel_id]
    
    # Check if the vessel_id is in the test set
    if vessel_id in test_df['vesselId'].values:
        vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
        
        # Split the data into train and validation sets
        x_train_port, x_val_port, y_train_port, y_val_port = train_test_split(vessel_train_df[features_port], vessel_train_df[target_port], test_size=0.3, random_state=False)
        
        # Initialize and train the model
        model_port = xgb.XGBRegressor(
            n_estimators=100,
            n_jobs=-1,
            early_stopping_rounds=50,
            learning_rate=0.01,
            max_depth=10,
        )
        
        model_port.fit(
            x_train_port, y_train_port,
            verbose=False,
            eval_set=[(x_train_port, y_train_port), (x_val_port, y_val_port)],
        )
        
        # Store the model in the dictionary
        vessel_models[vessel_id] = model_port
        
        # Predict the port_longitude and port_latitude for the current vessel in the test set
        preds = model_port.predict(vessel_test_df[features_port])
        test_df.loc[test_df['vesselId'] == vessel_id, 'predicted_port_longitude'] = preds[:, 0]
        test_df.loc[test_df['vesselId'] == vessel_id, 'predicted_port_latitude'] = preds[:, 1]

display(test_df.head())
# Out:
# Training models for each vessel: 100%|██████████| 688/688 [00:55<00:00, 12.45it/s]
#    ID  vesselId          time  scaling_factor            shippingLineId   CEU  \
# 0   0        86  1.715127e+09             0.3  61a8e672f9cba188601e84ac  7934
# 1   1       646  1.715127e+09             0.3  61be24574ea00ae59d0fe388  2500
# 2   2       619  1.715127e+09             0.3  61ec6303a8cafc0e93f0e8f3  1400
# 3   3       562  1.715127e+09             0.3  61be24564ea00ae59d0fe37a  5007
# 4   4         1  1.715127e+09             0.3  61ec94f1a8cafc0e93f0e92a  4902
#
#        DWT     GT  vesselType  breadth  ...  sin_hour  cos_hour  sin_weekday  \
# 0  31143.0  74255        83.0     32.0  ...       0.0       1.0     0.974928
# 1  13238.0   9984        14.0     20.0  ...       0.0       1.0     0.974928
# 2   7150.0  25995        21.0     27.0  ...       0.0       1.0     0.974928
# 3  13951.0  45959        83.0     30.2  ...       0.0       1.0     0.974928
# 4  12325.0  46800        83.0     31.0  ...       0.0       1.0     0.974928
#
#    cos_weekday  sin_month  cos_month   sin_day   cos_day  \
# 0    -0.222521        0.5  -0.866025  0.998717 -0.050649
# 1    -0.222521        0.5  -0.866025  0.998717 -0.050649
# 2    -0.222521        0.5  -0.866025  0.998717 -0.050649
# 3    -0.222521        0.5  -0.866025  0.998717 -0.050649
# 4    -0.222521        0.5  -0.866025  0.998717 -0.050649
#
#    predicted_port_longitude  predicted_port_latitude
# 0                -38.264271                32.542095
# 1                105.812416                49.213570
# 2                 17.410944                36.130802
# 3                128.680283                 0.846667
# 4                  5.214273                35.246525
#
# [5 rows x 24 columns]

# %%
from geopy.distance import geodesic
from joblib import Parallel, delayed

# Calculate the distance between the predicted and actual port coordinates

# Ensure each portId is unique
port_coordinates = ports_df[['portId', 'port_longitude', 'port_latitude']].drop_duplicates(subset='portId')
port_coordinates = port_coordinates.set_index('portId')

# Remove nan port coordinates
port_coordinates = port_coordinates.dropna()

# Fill missing values in test data
test_df['predicted_port_longitude'] = test_df['predicted_port_longitude'].fillna(test_df['predicted_port_longitude'].mean())
test_df['predicted_port_latitude'] = test_df['predicted_port_latitude'].fillna(test_df['predicted_port_latitude'].mean())

display(port_coordinates)

# Check for nan values in the predicted port coordinates
print(test_df['predicted_port_longitude'].isna().sum())

# Vectorized function to find the closest port
def find_closest_port_vectorized(predicted_lat, predicted_lon):
    predicted_port = (predicted_lat, predicted_lon)
    distances = port_coordinates.apply(lambda x: geodesic(predicted_port, (x['port_latitude'], x['port_longitude'])).m, axis=1)
    closest_port = distances.idxmin()
    return closest_port

# Apply the function in parallel
test_df['closest_port'] = Parallel(n_jobs=-1)(delayed(find_closest_port_vectorized)(row['predicted_port_latitude'], row['predicted_port_longitude']) for _, row in test_df.iterrows())

# Rename "closest_port" to "portId" and "predicted_port_longitude" to "port_longitude" and "predicted_port_latitude" to "port_latitude"
test_df = test_df.rename(columns={'closest_port': 'portId', 'predicted_port_longitude': 'port_longitude', 'predicted_port_latitude': 'port_latitude'})
# Out:
#                           port_longitude  port_latitude
# portId
# 61d36ed80a1807568ff9a064        3.067222      36.773611
# 61d36ed80a1807568ff9a065        7.772500      36.900556
# 61d36edf0a1807568ff9a070       -0.639722      35.712222
# 61d36ee00a1807568ff9a072        6.905833      36.887500
# 61d36ee10a1807568ff9a074     -170.690556     -14.274167
# ...                                  ...            ...
# 6367c622aa0cd188707a1eae       25.029460      51.624500
# 6367cb14aa0cd188707a1eaf       50.667890      26.201200
# 6367d9afaa0cd188707a1eb3       34.992790      29.519880
# 663cb287244f580d97afce53       -2.648735      51.471346
# 663cb48be894e2f07d1c69b2       50.616667      26.205546
#
# [1329 rows x 2 columns]
# 0

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Predict on the validation set
y_val_port_pred = model_port.predict(x_val_port)

# Calculate MAE and MSE
mae = mean_absolute_error(y_val_port, y_val_port_pred)
mse = mean_squared_error(y_val_port, y_val_port_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Absolute Error (MAE): 13.041074757120764
# Mean Squared Error (MSE): 310.9616755975336

# %%
# Label encode transform portId
le_portId = LabelEncoder()
le_portId.fit(pd.concat([train_df['portId'], test_df['portId']]))
train_df['portId'] = le_portId.transform(train_df['portId'])
test_df['portId'] = le_portId.transform(test_df['portId'])

# Label encode shippingLineId
le_shippingLineId = LabelEncoder()
le_shippingLineId.fit(pd.concat([train_df['shippingLineId'], test_df['shippingLineId']]))
train_df['shippingLineId'] = le_shippingLineId.transform(train_df['shippingLineId'])
test_df['shippingLineId'] = le_shippingLineId.transform(test_df['shippingLineId'])


display(test_df)
display(train_df)
# Out:
#           ID  vesselId          time  scaling_factor  shippingLineId   CEU  \
# 0          0        86  1.715127e+09             0.3               1  7934
# 1          1       646  1.715127e+09             0.3              18  2500
# 2          2       619  1.715127e+09             0.3              21  1400
# 3          3       562  1.715127e+09             0.3              15  5007
# 4          4         1  1.715127e+09             0.3              25  4902
# ...      ...       ...           ...             ...             ...   ...
# 51734  51734        49  1.715558e+09             0.1               0  6000
# 51735  51735       114  1.715558e+09             0.1               1  5849
# 51736  51736       633  1.715558e+09             0.1               8  6178
# 51737  51737       595  1.715558e+09             0.1              22   840
# 51738  51738        84  1.715558e+09             0.1               1  7620
#
#            DWT     GT  vesselType  breadth  ...  cos_hour  sin_weekday  \
# 0      31143.0  74255        83.0    32.00  ...  1.000000     0.974928
# 1      13238.0   9984        14.0    20.00  ...  1.000000     0.974928
# 2       7150.0  25995        21.0    27.00  ...  1.000000     0.974928
# 3      13951.0  45959        83.0    30.20  ...  1.000000     0.974928
# 4      12325.0  46800        83.0    31.00  ...  1.000000     0.974928
# ...        ...    ...         ...      ...  ...       ...          ...
# 51734  19670.0  59705        83.0    32.00  ...  0.965926    -0.781831
# 51735  15199.0  55598        83.0    32.00  ...  0.965926    -0.781831
# 51736  18770.0  59516        83.0    32.26  ...  0.965926    -0.781831
# 51737   9653.0  45923        21.0    30.00  ...  0.965926    -0.781831
# 51738  30386.0  71583        83.0    32.00  ...  0.965926    -0.781831
#
#        cos_weekday  sin_month  cos_month   sin_day   cos_day  port_longitude  \
# 0        -0.222521        0.5  -0.866025  0.998717 -0.050649      -38.264271
# 1        -0.222521        0.5  -0.866025  0.998717 -0.050649      105.812416
# 2        -0.222521        0.5  -0.866025  0.998717 -0.050649       17.410944
# 3        -0.222521        0.5  -0.866025  0.998717 -0.050649      128.680283
# 4        -0.222521        0.5  -0.866025  0.998717 -0.050649        5.214273
# ...            ...        ...        ...       ...       ...             ...
# 51734     0.623490        0.5  -0.866025  0.651372 -0.758758       14.254347
# 51735     0.623490        0.5  -0.866025  0.651372 -0.758758      107.464432
# 51736     0.623490        0.5  -0.866025  0.651372 -0.758758       88.138336
# 51737     0.623490        0.5  -0.866025  0.651372 -0.758758       24.028885
# 51738     0.623490        0.5  -0.866025  0.651372 -0.758758       -6.572028
#
#        port_latitude  portId
# 0          32.542095     728
# 1          49.213570     490
# 2          36.130802     627
# 3           0.846667     603
# 4          35.246525       3
# ...              ...     ...
# 51734      35.110756     240
# 51735      49.298180     490
# 51736      23.080423     125
# 51737      48.302139     824
# 51738      13.409203     596
#
# [51739 rows x 25 columns]
#                  time    cog   sog  rot  heading  navstat       etaRaw  \
# 0        1.704067e+09  284.0   0.7    0       88        0  01-09 23:00
# 1        1.704067e+09  109.6   0.0   -6      347        1  12-29 20:00
# 2        1.704067e+09  111.0  11.0    0      112        0  01-02 09:00
# 3        1.704067e+09   96.4   0.0    0      142        1  12-31 20:00
# 4        1.704067e+09  214.0  19.7    0      215        0  01-25 12:00
# ...               ...    ...   ...  ...      ...      ...          ...
# 1522060  1.715126e+09  359.1  13.4    0        1        0  05-08 05:00
# 1522061  1.715126e+09   12.3  17.1    0       13        0  05-10 03:00
# 1522062  1.715126e+09  269.8  14.9   -1      270        0  05-15 23:00
# 1522063  1.715126e+09    8.0  18.7    0        6        0  05-08 12:45
# 1522064  1.715126e+09  336.0  14.3    5      337        0  05-07 23:00
#
#          latitude  longitude  vesselId  ...  sin_minute  cos_minute  sin_hour  \
# 0       -34.74370  -57.85130        51  ...    0.000000    1.000000  0.000000
# 1         8.89440  -79.47939       198  ...    0.000000    1.000000  0.000000
# 2        39.19065  -76.47567       450  ...    0.104528    0.994522  0.000000
# 3       -34.41189  151.02067       114  ...    0.309017    0.951057  0.000000
# 4        35.88379   -5.91636       370  ...    0.309017    0.951057  0.000000
# ...           ...        ...       ...  ...         ...         ...       ...
# 1522060  52.19131   -5.82223       705  ...   -0.104528    0.994522 -0.258819
# 1522061  38.96142  -12.00502        89  ...   -0.104528    0.994522 -0.258819
# 1522062  49.71372   -5.22042       477  ...   -0.104528    0.994522 -0.258819
# 1522063  38.27895   10.78280       619  ...   -0.104528    0.994522 -0.258819
# 1522064  38.98635  -75.13275       660  ...   -0.104528    0.994522 -0.258819
#
#          cos_hour  sin_weekday  cos_weekday  sin_month  cos_month   sin_day  \
# 0        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 1        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 2        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 3        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# 4        1.000000     0.000000      1.00000        0.5   0.866025  0.201299
# ...           ...          ...          ...        ...        ...       ...
# 1522060  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522061  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522062  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522063  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
# 1522064  0.965926     0.781831      0.62349        0.5  -0.866025  0.988468
#
#           cos_day
# 0        0.979530
# 1        0.979530
# 2        0.979530
# 3        0.979530
# 4        0.979530
# ...           ...
# 1522060  0.151428
# 1522061  0.151428
# 1522062  0.151428
# 1522063  0.151428
# 1522064  0.151428
#
# [1522065 rows x 36 columns]

# %% [markdown]
# ### Predict cog, sog. rot and heading

# %%
# Define features and targets for cog, sog, heading, and rot
features_cog_sog_heading = ['vesselId', 'sin_minute', 'cos_minute', 'sin_hour', 'cos_hour', 'sin_weekday', 'cos_weekday', 'sin_month', 'cos_month', 'time', 'CEU', 'DWT', 'GT', 'vesselType', 'breadth', 'length', 'yearBuilt', 'port_longitude', 'port_latitude', 'portId']
targets_cog_sog_heading = ['cog', 'sog', 'rot', 'heading']

# Initialize dictionaries to store models for each target
cog_models = {}
sog_models = {}
rot_models = {}
heading_models = {}

# Get unique vessel IDs in the test set
unique_vessels_in_test = test_df['vesselId'].unique()

# Loop through each vessel and train models for cog, sog, rot, and heading
for vessel_id in tqdm(unique_vessels_in_test, desc="Training models for each vessel in test set"):
    # Filter the data for the current vessel
    vessel_train_df = train_df[train_df['vesselId'] == vessel_id]
    
    # Split the data into train and validation sets
    x_train_csh, x_val_csh, y_train_csh, y_val_csh = train_test_split(vessel_train_df[features_cog_sog_heading], vessel_train_df[targets_cog_sog_heading], test_size=0.3, random_state=False)
    
    # Initialize and train the model for cog
    model_cog = xgb.XGBRegressor(
        n_estimators=10000,
        n_jobs=-1,
        early_stopping_rounds=50,
        learning_rate=0.01,
        max_depth=10,
    )
    model_cog.fit(
        x_train_csh, y_train_csh['cog'],
        verbose=False,
        eval_set=[(x_train_csh, y_train_csh['cog']), (x_val_csh, y_val_csh['cog'])],
    )
    cog_models[vessel_id] = model_cog
    
    # Initialize and train the model for sog
    model_sog = xgb.XGBRegressor(
        n_estimators=1000,
        n_jobs=-1,
        early_stopping_rounds=50,
        learning_rate=0.01,
        max_depth=10,
    )
    model_sog.fit(
        x_train_csh, y_train_csh['sog'],
        verbose=False,
        eval_set=[(x_train_csh, y_train_csh['sog']), (x_val_csh, y_val_csh['sog'])],
    )
    sog_models[vessel_id] = model_sog
    
    # Initialize and train the model for rot
    model_rot = xgb.XGBRegressor(
        n_estimators=1000,
        n_jobs=-1,
        early_stopping_rounds=50,
        learning_rate=0.01,
        max_depth=10,
    )
    model_rot.fit(
        x_train_csh, y_train_csh['rot'],
        verbose=False,
        eval_set=[(x_train_csh, y_train_csh['rot']), (x_val_csh, y_val_csh['rot'])],
    )
    rot_models[vessel_id] = model_rot
    
    # Initialize and train the model for heading
    model_heading = xgb.XGBRegressor(
        n_estimators=1000,
        n_jobs=-1,
        early_stopping_rounds=50,
        learning_rate=0.01,
        max_depth=10,
    )
    model_heading.fit(
        x_train_csh, y_train_csh['heading'],
        verbose=False,
        eval_set=[(x_train_csh, y_train_csh['heading']), (x_val_csh, y_val_csh['heading'])],
    )
    heading_models[vessel_id] = model_heading
    
    # Predict cog, sog, rot, and heading for the current vessel in the test set
    vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
    test_df.loc[test_df['vesselId'] == vessel_id, 'cog'] = model_cog.predict(vessel_test_df[features_cog_sog_heading])
    test_df.loc[test_df['vesselId'] == vessel_id, 'sog'] = model_sog.predict(vessel_test_df[features_cog_sog_heading])
    test_df.loc[test_df['vesselId'] == vessel_id, 'rot'] = model_rot.predict(vessel_test_df[features_cog_sog_heading])
    test_df.loc[test_df['vesselId'] == vessel_id, 'heading'] = model_heading.predict(vessel_test_df[features_cog_sog_heading])

display(test_df.head())
# Out:
# Training models for each vessel in test set: 100%|██████████| 215/215 [13:10<00:00,  3.68s/it]
#    ID  vesselId          time  scaling_factor  shippingLineId   CEU      DWT  \
# 0   0        86  1.715127e+09             0.3               1  7934  31143.0
# 1   1       646  1.715127e+09             0.3              18  2500  13238.0
# 2   2       619  1.715127e+09             0.3              21  1400   7150.0
# 3   3       562  1.715127e+09             0.3              15  5007  13951.0
# 4   4         1  1.715127e+09             0.3              25  4902  12325.0
#
#       GT  vesselType  breadth  ...  cos_month   sin_day   cos_day  \
# 0  74255        83.0     32.0  ...  -0.866025  0.998717 -0.050649
# 1   9984        14.0     20.0  ...  -0.866025  0.998717 -0.050649
# 2  25995        21.0     27.0  ...  -0.866025  0.998717 -0.050649
# 3  45959        83.0     30.2  ...  -0.866025  0.998717 -0.050649
# 4  46800        83.0     31.0  ...  -0.866025  0.998717 -0.050649
#
#    port_longitude  port_latitude  portId         cog        sog       rot  \
# 0      -38.264271      32.542095     728  190.137894  -0.567610  5.637220
# 1      105.812416      49.213570     490  176.242844   4.355990  1.375542
# 2       17.410944      36.130802     627  157.150513  18.066269  0.263022
# 3      128.680283       0.846667     603  181.905670   2.525155 -0.360059
# 4        5.214273      35.246525       3  258.532745   9.305189  0.301718
#
#       heading
# 0  228.551483
# 1  137.288345
# 2  226.956635
# 3  148.733383
# 4  231.195923
#
# [5 rows x 29 columns]

# %%
# Evaluate the models for cog, sog, and heading
# Predict on the validation set
y_val_cog_pred = model_cog.predict(x_val_csh)
y_val_sog_pred = model_sog.predict(x_val_csh)
y_val_rot_pred = model_rot.predict(x_val_csh)
y_val_heading_pred = model_heading.predict(x_val_csh)

# Calculate MAE and MSE for cog
mae_cog = mean_absolute_error(y_val_csh['cog'], y_val_cog_pred)
mse_cog = mean_squared_error(y_val_csh['cog'], y_val_cog_pred)

# Calculate MAE and MSE for sog
mae_sog = mean_absolute_error(y_val_csh['sog'], y_val_sog_pred)
mse_sog = mean_squared_error(y_val_csh['sog'], y_val_sog_pred)

# Calculate MAE and MSE for rot
mae_rot = mean_absolute_error(y_val_csh['rot'], y_val_rot_pred)
mse_rot = mean_squared_error(y_val_csh['rot'], y_val_rot_pred)

# Calculate MAE and MSE for heading
mae_heading = mean_absolute_error(y_val_csh['heading'], y_val_heading_pred)
mse_heading = mean_squared_error(y_val_csh['heading'], y_val_heading_pred)


print(f"Mean Absolute Error (MAE) for COG: {mae_cog}")
print(f"Mean Squared Error (MSE) for COG: {mse_cog}")
print(f"Mean Absolute Error (MAE) for SOG: {mae_sog}")
print(f"Mean Squared Error (MSE) for SOG: {mse_sog}")
print(f"Mean Absolute Error (MAE) for ROT: {mae_rot}")
print(f"Mean Squared Error (MSE) for ROT: {mse_rot}")
print(f"Mean Absolute Error (MAE) for Heading: {mae_heading}")
print(f"Mean Squared Error (MSE) for Heading: {mse_heading}")
# Out:
# Mean Absolute Error (MAE) for COG: 29.571196231213246
# Mean Squared Error (MSE) for COG: 2775.133270192551
# Mean Absolute Error (MAE) for SOG: 0.8056702515826775
# Mean Squared Error (MSE) for SOG: 3.0344420987072103
# Mean Absolute Error (MAE) for ROT: 0.6978021978021978
# Mean Squared Error (MSE) for ROT: 88.62087912087912
# Mean Absolute Error (MAE) for Heading: 15.617217724139874
# Mean Squared Error (MSE) for Heading: 1524.2303490841934

# %% [markdown]
# ### Fit model

# %%
from tqdm import tqdm

features_main = ['vesselId', 'sin_minute', 'cos_minute', 'sin_hour', 'cos_hour', 'sin_weekday', 'cos_weekday', 'sin_month', 'cos_month', 'time', 'CEU', 'DWT', 'GT', 'vesselType', 'breadth', 'length', 'yearBuilt', 'port_longitude', 'port_latitude', 'portId', 'cog', 'sog', 'rot', 'heading']
targets_main = ['latitude', 'longitude']

# Get unique vessel IDs
unique_vessels = train_df['vesselId'].unique()

# Initialize a dictionary to store models for each vessel
vessel_models = {}

# Loop through each vessel and train a model
# Filter the unique vessel IDs that are present in the test set
unique_vessels_in_test = test_df['vesselId'].unique()

for vessel_id in tqdm(unique_vessels_in_test, desc="Training models for each vessel in test set"):
    # Filter the data for the current vessel
    vessel_train_df = train_df[train_df['vesselId'] == vessel_id]
    
    # Split the data into train and validation sets
    x_train, x_val, y_train, y_val = train_test_split(vessel_train_df[features_main], vessel_train_df[targets_main], test_size=0.3, random_state=False)

    
    # Initialize and train the model
    model = xgb.XGBRegressor(
        n_estimators=10000,
        n_jobs=-1,
        early_stopping_rounds=50,
        learning_rate=0.01,
        max_depth=10,
    )
    
    model.fit(
        x_train, y_train,
        verbose=False,
        eval_set=[(x_train, y_train), (x_val, y_val)],
    )
    
    # Store the model in the dictionary
    vessel_models[vessel_id] = model
    
    # Predict the latitude and longitude for the current vessel in the test set
    vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
    preds = model.predict(vessel_test_df[features_main])
    test_df.loc[test_df['vesselId'] == vessel_id, 'latitude_predicted'] = preds[:, 0]
    test_df.loc[test_df['vesselId'] == vessel_id, 'longitude_predicted'] = preds[:, 1]
# Out:
# Training models for each vessel in test set: 100%|██████████| 215/215 [28:21<00:00,  7.91s/it]

# %% [markdown]
# ### Predict

# %%
# Give metrics on the model
print(model.score(x_train, y_train))
print(model.score(x_val, y_val))
# Out:
# 0.9999644160270691
# 0.9636021256446838

# %%
# Initialize an empty list to store predictions
all_preds = []

# Loop through each vessel and predict positions
for vessel_id in unique_vessels:
    # Filter the test data for the current vessel
    vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
    
    # Check if there is a model for the current vessel
    if vessel_id in vessel_models:
        model = vessel_models[vessel_id]
        
        # Predict positions
        preds = model.predict(vessel_test_df[features_main])
        
        # Store the predictions
        all_preds.append((vessel_test_df['ID'], preds))

# Combine all predictions into a single DataFrame
preds_df = pd.concat([pd.DataFrame({'ID': ids, 'longitude_predicted': pred[:, 0], 'latitude_predicted': pred[:, 1]}) for ids, pred in all_preds])

# Merge the predictions with the test_df
#test_df = test_df.merge(preds_df, on='ID', how='left')

display(test_df.head())
# Out:
#    ID  vesselId          time  scaling_factor  shippingLineId   CEU      DWT  \
# 0   0        86  1.715127e+09             0.3               1  7934  31143.0
# 1   1       646  1.715127e+09             0.3              18  2500  13238.0
# 2   2       619  1.715127e+09             0.3              21  1400   7150.0
# 3   3       562  1.715127e+09             0.3              15  5007  13951.0
# 4   4         1  1.715127e+09             0.3              25  4902  12325.0
#
#       GT  vesselType  breadth  ...   cos_day  port_longitude  port_latitude  \
# 0  74255        83.0     32.0  ... -0.050649      -38.264271      32.542095
# 1   9984        14.0     20.0  ... -0.050649      105.812416      49.213570
# 2  25995        21.0     27.0  ... -0.050649       17.410944      36.130802
# 3  45959        83.0     30.2  ... -0.050649      128.680283       0.846667
# 4  46800        83.0     31.0  ... -0.050649        5.214273      35.246525
#
#    portId         cog        sog       rot     heading  latitude_predicted  \
# 0     728  190.137894  -0.567610  5.637220  228.551483           31.159044
# 1     490  176.242844   4.355990  1.375542  137.288345           22.690378
# 2     627  157.150513  18.066269  0.263022  226.956635           37.636482
# 3     603  181.905670   2.525155 -0.360059  148.733383           33.803020
# 4       3  258.532745   9.305189  0.301718  231.195923           35.711189
#
#    longitude_predicted
# 0           -75.009773
# 1           107.676010
# 2            12.331141
# 3           134.200058
# 4             3.244443
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Eksporter til csv

# %%
submission_df = test_df[['ID', 'longitude_predicted','latitude_predicted']]

# Rename columns
submission_df = submission_df.rename(columns={'longitude_predicted': 'longitude_predicted', 'latitude_predicted': 'latitude_predicted'})

submission_df.to_csv('predictions_24oct.csv', index=False)
print('Få den jævla "predictions.csv" filen inn på Kaggle og se om det funker')
# Out:
# Få den jævla "predictions.csv" filen inn på Kaggle og se om det funker

# %%
from geopy.distance import geodesic
submission_best = pd.read_csv('submission_24_10.csv')
submission_today = pd.read_csv('predictions_24oct.csv')
latitude_best = submission_best['latitude_predicted']
longitude_best = submission_best['longitude_predicted']
latitudes_today = submission_today['latitude_predicted']
longitudes_today = submission_today['longitude_predicted']
distances = []
weights = test_df['scaling_factor']
for i in range(len(longitude_best)):
    distance = geodesic((latitude_best[i], longitude_best[i]), 
                        (latitudes_today[i], longitudes_today[i])).meters
    distances.append(distance*weights[i])

print((np.mean(distances)) /1000)
# Out:
# 336.19077853309807
